# %% [markdown]
# # What this script does

# %% [markdown]
# Here we download all the avilable enforcement letters issued to nursing homes by the Washington State Department of Social and Health Services (DSHS).
#
# The letters available for download are updated each month, so we ran this process a few times since March 2020. In various palces in this script, you will find converted into comments lines of code corresponding to older downloads.

# %% [markdown]
# # A. Settings

# %%
import pandas as pd
import requests
import bs4
import re
import time
from os import listdir

# %% [markdown]
# # B. Listing file

# %% [markdown]
# The DSHS's [Nursing Home Facilities Locator](https://fortress.wa.gov/dshs/adsaapps/lookup/NHPubLookup.aspx) provides a CSV file that contains:
# - A list of all the nursing homes regestered at the DSHS
# - The links where the ALTSA PDF reports issued to those homes can be downloaded
#
# As we mention above, this CSV file is updated monthly. Each time, letters issued in the earliest month of th 3-year period are dumped and those issued during the latest one are added. That is why we ran this download a few times, as can be seen by lines in the code that were left as comments, corresponding to those downloads.

# %%
# Pull the original data
# df_list_orig = pd.read_csv('../A_source_data/DSHS/NFListing_2020-03.csv')
# df_list_orig = pd.read_csv('../A_source_data/DSHS/NFListing_2020-06-09.csv')
# df_list_orig = pd.read_csv('../A_source_data/DSHS/NFListing_2020-06-24.csv')
# df_list_orig = pd.read_csv('../A_source_data/DSHS/NFListing_2020-07-16.csv')
# df_list_orig = pd.read_csv('../A_source_data/DSHS/NFListing_2020-08-20.csv')
df_list_orig = pd.read_csv('../A_source_data/DSHS/NFListing_2020-09-08.csv')

# Create a workable copy of the df_list
df_list = df_list_orig.copy()
df_list.columns = df_list.columns.str.strip().str.lower().str.replace('\s', '_')

# %% [markdown]
# ## Getting to know the listing file

# %%
df_list.head()
# Out:
#    nf_location_num  nf_loc_region_cde nf_loc_street_address nf_loc_city  \
# 0            19800                  1        495 N 13th Ave     Othello
# 1             4400                  1          1242 11TH ST   CLARKSTON
# 2            20400                  1  1508 WEST 7TH AVENUE   KENNEWICK
# 3            20500                  1     44 GOETHALS DRIVE    RICHLAND
# 4            40660                  1         2702 S Ely St   Kennewick
#
#    nf_loc_zip_cde  nf_loc_phone_num  nf_loc_fax_num nf_mailing_address  \
# 0           99344      5.094890e+09             NaN     495 N 13th Ave
# 1           99403      5.097583e+09    5.097519e+09         PO BOX 159
# 2           99336      5.095869e+09    5.095864e+09     1508 W 7TH AVE
# 3           99352      5.099431e+09    5.099435e+09     44 GOETHALS DR
# 4           99337      5.095826e+09    5.094972e+09      2702 S Ely St
#
#   nf_mailing_city nf_mailing_state  ...  rcsunit total_beds_nf_bed_count  \
# 0         Othello               WA  ...        A                      39
# 1       CLARKSTON               WA  ...        A                      90
# 2       KENNEWICK               WA  ...        D                     136
# 3        RICHLAND               WA  ...        D                     104
# 4       Kennewick               WA  ...        D                      53
#
#    xviii_beds_nf_bed_count  xix_beds_nf_bed_count t1819_beds_nf_bed_count  \
# 0                      NaN                    NaN                    39.0
# 1                      NaN                    NaN                    90.0
# 2                      NaN                    NaN                   136.0
# 3                      NaN                    NaN                   104.0
# 4                      0.0                    0.0                    53.0
#
#   fain_id nf_bed_type_desc has_reports?  \
# 0   43484      Title 18/19          Yes
# 1   43575      Title 18/19          Yes
# 2   43505      Title 18/19          Yes
# 3   43507      Title 18/19          Yes
# 4   44102      Title 18/19          Yes
#
#                                     reports_location unnamed:_32
# 0  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 1  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 2  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 3  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 4  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
#
# [5 rows x 33 columns]

# %%
df_list.tail()
# Out:
#      nf_location_num  nf_loc_region_cde      nf_loc_street_address  \
# 200            20000                  1               721 OTIS AVE
# 201             6000                  1     3801 SUMMITVIEW AVENUE
# 202            22200                  1              802 W 3rd Ave
# 203            10300                  1          4007 TIETON DRIVE
# 204              700                  1  609 SPEYERS ROAD  B 39-15
#
#     nf_loc_city  nf_loc_zip_cde  nf_loc_phone_num  nf_loc_fax_num  \
# 200   SUNNYSIDE       989442328      5.098372e+09    5.098373e+09
# 201      YAKIMA           98902      5.099666e+09    5.098533e+09
# 202   Toppenish           98948      5.098654e+09    5.098654e+09
# 203      YAKIMA           98908      5.099664e+09    5.099661e+09
# 204       SELAH       989421099      5.096981e+09    5.096972e+09
#
#           nf_mailing_address nf_mailing_city nf_mailing_state  ...  rcsunit  \
# 200             721 OTIS AVE       SUNNYSIDE               WA  ...        D
# 201      3801 SUMMITVIEW AVE          YAKIMA               WA  ...        D
# 202            802 W 3rd Ave       Toppenish               WA  ...        D
# 203           4007 TIETON DR          YAKIMA               WA  ...        D
# 204  609 SPEYERS RD  B 39-15           SELAH               WA  ...        D
#
#     total_beds_nf_bed_count  xviii_beds_nf_bed_count  xix_beds_nf_bed_count  \
# 200                      80                      NaN                    NaN
# 201                      78                      0.0                    NaN
# 202                      75                      NaN                    0.0
# 203                      75                      NaN                    0.0
# 204                     160                      NaN                  160.0
#
#     t1819_beds_nf_bed_count fain_id nf_bed_type_desc has_reports?  \
# 200                    80.0   43574      Title 18/19          Yes
# 201                    78.0   42645      Title 18/19          Yes
# 202                    75.0   43479      Title 18/19          Yes
# 203                    75.0   43516      Title 18/19          Yes
# 204                     NaN   43608         Title 19          Yes
#
#                                       reports_location unnamed:_32
# 200  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 201  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 202  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 203  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 204  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ### What field do we use to ID facilities?

# %%
num_rows_orig = len(df_list) # We will use this value for consistency tests later.

print('Number of rows =', num_rows_orig)
print('Number of unique nf_location_num =', df_list['nf_location_num'].nunique())
print('Number of unique fain_id =', df_list['fain_id'].nunique())
print('Number of unique nf_name =', df_list['nf_name'].nunique())
# Out:
# Number of rows = 205
# Number of unique nf_location_num = 205
# Number of unique fain_id = 205
# Number of unique nf_name = 205

# %% [markdown]
# It seems there are various variables uniquely identify each facility. We will use **fain_id** as the unique ID fore each facility.

# %% [markdown]
# ### Subsetting: Only facilities that have reports

# %% [markdown]
# How many facilities have reports and how many don't?

# %%
df_list['has_reports?'].value_counts(dropna=False)
# Out:
# Yes    205
# Name: has_reports?, dtype: int64

# %%
print('Out of the', len(df_list), 'nursing homes,', (df_list['has_reports?'] == 'Yes').sum(), 
      'have at least one report issued to them—whether inspection reports, enforcement letters, etc.')
# Out:
# Out of the 205 nursing homes, 205 have at least one report issued to them—whether inspection reports, enforcement letters, etc.

# %%
# # Make a df_list for the facilities with no reports
# df_list_no_reports = df_list[df_list['has_reports?'] == 'No']
# df_list_no_reports = df_list_no_reports.reset_index(drop=True)
# df_list_no_reports

# # Filter out from dd_fac those facilities with no reports
# df_list = df_list[df_list['has_reports?'] == 'Yes']
# df_list = df_list.reset_index(drop=True)

# # Confirm that the facilities marked as having no reports show no query link
# assert df_list_no_reports['reports_location'].str.strip().all() == ''

# # Confirm no rows were lost during the dataframe split
# assert len(df_list) + len(df_list_no_reports) == num_rows_orig

# %%
# Any nursing homes with no reports?
print(df_list['has_reports?'].value_counts(dropna=False))
assert df_list['reports_location'].str.strip().all() != ''
# Out:
# Yes    205
# Name: has_reports?, dtype: int64

# %% [markdown]
# # C. The long looping road to downloading

# %%
# download_path = '/Volumes/files/COVID19/Manuel_RCF_Data/State_DSHS/ALTSA_reports/NH_3333/'
# download_path = '/Volumes/files/COVID19/Manuel_RCF_Data/State_DSHS/ALTSA_reports/NH_enforcement_letters_2020-06-09/'
# download_path = '/Volumes/files/COVID19/Manuel_RCF_Data/State_DSHS/ALTSA_reports/NH_enforcement_letters_2020-06-24/'
# download_path = '/Volumes/files/COVID19/Manuel_RCF_Data/State_DSHS/ALTSA_reports/NH_enforcement_letters_2020-07-16/'
# download_path = '/Volumes/files/COVID19/Manuel_RCF_Data/State_DSHS/ALTSA_reports/NH_enforcement_letters_2020-08-20/'
download_path = '/Volumes/files/COVID19/Manuel_RCF_Data/State_DSHS/ALTSA_reports/NH_enforcement_letters_2020-09-08/'

# As we dowload each report, we will save some of its metadata in this new df_list:
df_metadata = pd.DataFrame(columns = ['fain_id', 'nf_name', 'pdf_name', 
                                      'rep_type', 'rep_date', 'url','download_record'])


# Each iteration of this first loop correspond to a single facility
for index, row in df_list.iterrows():
    
    print(index, '|', row['nf_name'])

    # Send a URL request to the site that contains all the links to each of the reports for a single facility.
    page = requests.get(row['reports_location'])
    soup = bs4.BeautifulSoup(page.text, 'html.parser')
    
    # The list of links to each of the reports is contained it a 'div' table with id='content_results'
    table = soup.find('div', {"id": "content_results"})
    
    # Each of the following table elements contains the URL of each PDF report
    ls_li = table.find_all('li')

    # Each iteration of this second loop corresponds to a single pdf report (from a single facility)
    for li in ls_li:    
        # We are only looking for enforcement letters
        if 'enforcement' in li.find('a').contents[0].lower():

            # Obtain some metadata from the report
            pdf_url = li.find('a').get('href')
            pdf_name = pdf_url.split("/")[-1]
            rep_type = re.search('\d{2}\/\d{4}\s-\s(.*)$', li.find('a').contents[0]).groups()[0]
            rep_date = re.search('(\d{2}\/\d{4})', li.find('a').contents[0]).groups()[0]

            # Save down the pdf
            pdf = requests.get('https://fortress.wa.gov' + pdf_url)
            open(download_path + pdf_name, 'wb').write(pdf.content)
            
            # Save the report's metadata in 'df_metadata'
            new_record = {'fain_id':row['fain_id'], 
                          'nf_name':row['nf_name'], 
                          'pdf_name':pdf_name, 
                          'rep_type':rep_type, 
                          'rep_date':rep_date,
                          'url':'https://fortress.wa.gov' + pdf_url,
                          'download_record':time.ctime()}
            df_metadata = df_metadata.append(new_record, ignore_index=True)
            del(new_record)
        
        time.sleep(0.5)
# Out:
# 0 | AVALON CARE CENTER - OTHELLO, LLC
# 1 | PRESTIGE CARE & REHABILITATION - CLARKSTON
# 2 | LIFE CARE CENTER OF KENNEWICK
# 3 | LIFE CARE CENTER OF RICHLAND
# 4 | Regency Canyon Lakes Rehabilitation and Nursing Center
# 5 | RICHLAND REHABILITATION CENTER
# 6 | Cashmere Care Center
# 7 | Colonial Vista Post Acute & Rehabilitation Center
# 8 | Regency Wenatchee Rehabilitation and Nursing Center
# 9 | AVAMERE OLYMPIC REHABILITATION OF SEQUIM
# 10 | Crestwood Health & Rehabilitation Center
# 11 | FORKS COMMUNITY HOSPITAL LTC UNIT
# 12 | Sequim Health & Rehabilitation Center
# 13 | Avamere Rehabilitation of Cascade Park
# 14 | Brookfield Health and Rehabilitation of Cascadia
# 15 | DISCOVERY NURSING & REHAB OF VANCOUVER
# 16 | Fort Vancouver Post Acute
# 17 | Manor Care Health Services - Salmon Creek
# 18 | PRESTIGE CARE & REHABILITATION - CAMAS
# 19 | The Oaks at Timberline
# 20 | Vancouver Specialty and Rehabilitative Care
# 21 | WOODLAND CONVALESCENT CENTER
# 22 | BOOKER REST HOME ANNEX
# 23 | Americana Health and Rehabilitation Center
# 24 | BEACON HILL REHABILITATION
# 25 | Frontier Rehabilitation and Extended Care
# 26 | AVALON HEALTH & REHABILITATION CENTER - PASCO
# 27 | COLUMBIA BASIN HOSPITAL
# 28 | COLUMBIA CREST CENTER
# 29 | LAKE RIDGE CENTER
# 30 | MCKAY HEALTHCARE & REHAB CENTER
# 31 | GRAYS HARBOR HEALTH & REHABILITATION CENTER
# 32 | MONTESANO HEALTH & REHABILITATION
# 33 | PACIFIC CARE AND REHABILITATION
# 34 | CAREAGE OF WHIDBEY
# 35 | LIFE CARE CENTER OF PORT TOWNSEND
# 36 | Advanced Post Acute
# 37 | AVALON CARE CENTER - FEDERAL WAY, LLC
# 38 | BAILEY-BOUSHAY HOUSE
# 39 | BALLARD CENTER
# 40 | BAYVIEW MANOR
# 41 | BENSON HEIGHTS REHABILITATION CENTER
# 42 | Briarwood at Timber Ridge
# 43 | Burien Nursing and Rehabilitation Center
# 44 | Canterbury House
# 45 | CAROLINE KLINE GALLAND HOME, THE
# 46 | COLUMBIA LUTHERAN HOME
# 47 | CORWIN CENTER AT EMERALD HEIGHTS
# 48 | COVENANT SHORES HEALTH CENTER
# 49 | Enumclaw Health and Rehabilitation Center
# 50 | FIRCREST SCHOOL PAT N
# 51 | FOSS HOME AND VILLAGE
# 52 | Garden Terrace Healthcare Center of Federal Way
# 53 | HALLMARK MANOR
# 54 | HEARTHSTONE, THE
# 55 | Issaquah Nursing & Rehabilitation Center
# 56 | JUDSON PARK HEALTH CENTER
# 57 | KIN ON HEALTH CARE CENTER
# 58 | Lea Hill Rehabilitation and Care Center
# 59 | LIFE CARE CENTER OF FEDERAL WAY
# 60 | LIFE CARE CENTER OF KIRKLAND
# 61 | MIRABELLA
# 62 | MISSION HEALTHCARE AT BELLEVUE
# 63 | Mission Healthcare at Renton
# 64 | North Auburn Rehabilitation & Health Center
# 65 | Paramount Rehabilitation and Nursing
# 66 | Park Ridge Care Center
# 67 | PARK SHORE
# 68 | Park West Care Center
# 69 | PROVIDENCE MARIANWOOD
# 70 | PROVIDENCE MOUNT ST VINCENT
# 71 | QUEEN ANNE HEALTHCARE
# 72 | REDMOND CARE AND REHABILITATION CENTER
# 73 | Regency North Bend Rehabilitation and Nursing Center
# 74 | Renton Nursing and Rehabilitation Center
# 75 | RICHMOND BEACH REHAB
# 76 | SAINT ANNE NURSING AND REHABILITATION CENTER
# 77 | SEA MAR COMMUNITY CARE CENTER
# 78 | Seattle Medical Post Acute Care
# 79 | SHORELINE HEALTH AND REHABILITATION
# 80 | STAFFORD HEALTHCARE
# 81 | SUNRISE HAVEN
# 82 | Talbot Center for Rehabilitation and Healthcare
# 83 | THE SPRINGS AT PACIFIC REGENT
# 84 | THE TERRACES AT SKYLINE
# 85 | Washington Care Center
# 86 | WESLEY HOMES HEALTH CENTER
# 87 | Bainbridge Island Health and Rehabilitation Center
# 88 | Bremerton Convalescent & Rehabilitation Center
# 89 | Forest Ridge Health & Rehabilitation Center
# 90 | LIFE CARE CENTER OF PORT ORCHARD
# 91 | MARTHA & MARY HEALTH SERVICES
# 92 | Northwoods Lodge
# 93 | STAFFORD HEALTHCARE AT BELMONT
# 94 | STAFFORD HEALTHCARE AT RIDGEMONT
# 95 | WASHINGTON VETERANS HOME-RETSIL
# 96 | PRESTIGE POST-ACUTE AND REHAB CENTER - KITTITAS
# 97 | Prestige Post-Acute and Rehab Center - Centralia
# 98 | Riverside Nursing & Rehabilitation Center
# 99 | SHARON CARE CENTER
# 100 | Fir Lane Health & Rehabilitation Center
# 101 | Shelton Health and Rehabilitation Center
# 102 | COLVILLE TRIBAL CONVALESCENT CENTER
# 103 | NORTH VALLEY HOSPITAL
# 104 | Regency Harmony House Rehab and Nursing Center
# 105 | REGENCY OMAK
# 106 | WILLAPA HARBOR HEALTH & REHAB
# 107 | Alaska Gardens Health and Rehabilitation Center
# 108 | Avamere at Pacific Ridge
# 109 | AVAMERE HERITAGE REHABILITATION OF TACOMA
# 110 | Avamere Transitional Care of Puget Sound
# 111 | COTTESMORE OF LIFE CARE
# 112 | FRANKE TOBEY JONES
# 113 | Heartwood Extended Healthcare
# 114 | Heron's Key
# 115 | LIFE CARE CENTER OF PUYALLUP
# 116 | Life Care Center of South Hill
# 117 | Linden Grove Health Care Center
# 118 | Manor Care Health Services (Gig Harbor)
# 119 | Manor Care Health Services (Tacoma)
# 120 | Orchard Park Health Care & Rehabilitation Center
# 121 | PARK ROSE CARE CENTER
# 122 | PUYALLUP NURSING AND REHABILITATION CENTER
# 123 | RAINIER REHABILITATION
# 124 | TACOMA LUTHERAN RETIREMENT COMMUNITY
# 125 | Tacoma Nursing and Rehabilitation Center
# 126 | The Oaks at Lakewood
# 127 | University Place Rehabilitation Center
# 128 | WASHINGTON SOLDIERS HOME
# 129 | LIFE CARE CENTER OF MOUNT VERNON
# 130 | LIFE CARE CENTER OF SKAGIT VALLEY
# 131 | MIRA VISTA CARE CENTER
# 132 | PRESTIGE CARE & REHABILITATION - BURLINGTON
# 133 | Soundview Rehabilitation and Health Care Inc
# 134 | Aldercrest Health & Rehabilitation Center
# 135 | ARLINGTON HEALTH AND REHABILITATION
# 136 | BETHANY AT PACIFIC
# 137 | BETHANY AT SILVER LAKE
# 138 | BOTHELL HEALTH CARE
# 139 | EVERETT CENTER
# 140 | Everett Transitional Care Services
# 141 | Josephine Caring Community
# 142 | LYNNWOOD POST ACUTE REHABILITATION CENTER
# 143 | Manor Care Health Services (Lynnwood)
# 144 | Marysville Care Center
# 145 | MOUNTAIN VIEW REHABILITATION AND CARE CENTER
# 146 | Prestige Post-Acute and Rehab Center - Edmonds
# 147 | REGENCY CARE CENTER AT MONROE
# 148 | Snohomish Health and Rehabilitation
# 149 | SUNRISE VIEW CONVALESCENT CENTER
# 150 | View Ridge Care Center
# 151 | WARM BEACH HEALTH CARE CENTER
# 152 | ALDERWOOD MANOR
# 153 | AVALON CARE CENTER AT NORTHPOINTE
# 154 | CHENEY CARE CENTER
# 155 | Franklin Hills Health & Rehabilitation Center
# 156 | Good Samaritan Society - Spokane Valley
# 157 | LAKELAND VILLAGE NURSING FACILITY
# 158 | Manor Care Health Services (Spokane)
# 159 | North Central Care Center
# 160 | PROVIDENCE ST JOSEPH CARE CENTER
# 161 | REGENCY AT NORTHPOINTE
# 162 | ROCKWOOD AT HAWTHORNE
# 163 | ROCKWOOD SOUTH HILL
# 164 | Royal Park Health and Rehabilitation
# 165 | SPOKANE VETERAN'S HOME
# 166 | SULLIVAN PARK CARE CENTER
# 167 | Sunshine Health & Rehab
# 168 | The Gardens on University
# 169 | TOUCHMARK ON SOUTH HILL
# 170 | Buena Vista Healthcare
# 171 | PRESTIGE CARE & REHABILITATION - PINEWOOD TERRACE
# 172 | Manor Care Health Services - Lacey
# 173 | Olympia Transitional Care and Rehabilitation
# 174 | PANORAMA CITY CONVALESCENT & REHAB CENTER
# 175 | PROVIDENCE MOTHER JOSEPH CARE CENTER
# 176 | Puget Sound Healthcare Center
# 177 | Regency Olympia Rehabilitation And Nursing Center
# 178 | Roo Lan Health & Rehab
# 179 | PARK MANOR REHABILITATION CENTER
# 180 | REGENCY AT THE PARK
# 181 | WASHINGTON ODD FELLOWS HOME
# 182 | Washington State Walla Walla Veterans Home
# 183 | Alderwood Park Health and Rehabilitation
# 184 | AVAMERE BELLINGHAM HEALTH CARE & REHABILITATION
# 185 | CHRISTIAN HEALTH CARE CENTER
# 186 | Good Samaritan Society - Stafholt
# 187 | Highland Health and Rehabilitation
# 188 | MT BAKER CARE CENTER
# 189 | North Cascades Health and Rehabilitation Center
# 190 | Shuksan Rehabilitation and Health Care
# 191 | ST FRANCIS OF BELLINGHAM
# 192 | AVALON CARE CENTER - PULLMAN
# 193 | Whitman Health and Rehabilitation Center
# 194 | CRESCENT HEALTH CARE, INC.
# 195 | EMERALD CARE
# 196 | GARDEN VILLAGE
# 197 | GOOD SAMARITAN HEALTH CARE CENTER
# 198 | LANDMARK CARE AND REHABILITATION
# 199 | PRESTIGE CARE & REHABILITATION - PARKSIDE
# 200 | PRESTIGE CARE & REHABILITATION - SUNNYSIDE
# 201 | SUMMITVIEW HEALTHCARE CENTER
# 202 | TOPPENISH NURSING & REHAB CENTER
# 203 | WILLOW SPRINGS CARE AND REHABILITATION
# 204 | YAKIMA VALLEY SCHOOL

# %%
# df_metadata = pd.read_csv('../C_output_data/download_metadata_2020-03.csv')
# df_metadata = pd.read_csv('../C_output_data/download_metadata_2020-06-09.csv')
# df_metadata = pd.read_csv('../C_output_data/download_metadata_2020-06-24.csv')
# df_metadata = pd.read_csv('../C_output_data/download_metadata_2020-07-16.csv')
# df_metadata = pd.read_csv('../C_output_data/download_metadata_2020-08-20.csv')
# df_metadata = pd.read_csv('../C_output_data/download_metadata_2020-09-08.csv')

# df_metadata.to_csv('../C_output_data/download_metadata_2020-03.csv', index=False)
# df_metadata.to_csv('../C_output_data/download_metadata_2020-06-09.csv', index=False)
# df_metadata.to_csv('../C_output_data/download_metadata_2020-06-24.csv', index=False)
# df_metadata.to_csv('../C_output_data/download_metadata_2020-07-16.csv', index=False)
# df_metadata.to_csv('../C_output_data/download_metadata_2020-08-20.csv', index=False)
df_metadata.to_csv('../C_output_data/download_metadata_2020-09-08.csv', index=False)

# %% [markdown]
# # D. Consistency tests

# %%
df_metadata.head()
# Out:
#   fain_id                                     nf_name  \
# 0   43484           AVALON CARE CENTER - OTHELLO, LLC
# 1   43484           AVALON CARE CENTER - OTHELLO, LLC
# 2   43575  PRESTIGE CARE & REHABILITATION - CLARKSTON
# 3   43575  PRESTIGE CARE & REHABILITATION - CLARKSTON
# 4   43575  PRESTIGE CARE & REHABILITATION - CLARKSTON
#
#                                             pdf_name            rep_type  \
# 0  Avalon Care Center - Othello (G, CMP, CF) 5 3 ...  Enforcement Letter
# 1  Avalon Care Center - Othello (Hx E, prior D) 8...  Enforcement Letter
# 2  Prestige Care Clarkston (Hx E prior D) 6 21 19...  Enforcement Letter
# 3  Prestige Care - Clarkston (Hx D prior E, CMP) ...  Enforcement Letter
# 4   Prestige Clarkston (Past Non J, CMP) 1 26 18.pdf  Enforcement Letter
#
#   rep_date                                                url  \
# 0  05/2019  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
# 1  08/2018  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
# 2  07/2019  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
# 3  06/2018  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
# 4  02/2018  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
#
#             download_record
# 0  Tue Sep  8 15:09:11 2020
# 1  Tue Sep  8 15:09:12 2020
# 2  Tue Sep  8 15:09:21 2020
# 3  Tue Sep  8 15:09:22 2020
# 4  Tue Sep  8 15:09:23 2020

# %%
df_metadata.tail()
# Out:
#     fain_id               nf_name  \
# 766   43608  YAKIMA VALLEY SCHOOL
# 767   43608  YAKIMA VALLEY SCHOOL
# 768   43608  YAKIMA VALLEY SCHOOL
# 769   43608  YAKIMA VALLEY SCHOOL
# 770   43608  YAKIMA VALLEY SCHOOL
#
#                                             pdf_name            rep_type  \
# 766  Yakima Valley School (Hx E prior D) 7 11 19.pdf  Enforcement Letter
# 767      Yakima Valley School (GG, CMP) 11 13 18.pdf  Enforcement Letter
# 768        Yakima Valley School (G, CMP) 7 23 18.pdf  Enforcement Letter
# 769   Yakima Valley School (Hx E prior E) 6 4 18.pdf  Enforcement Letter
# 770        Yakima Vally School (GG, CMP) 1 23 18.pdf  Enforcement Letter
#
#     rep_date                                                url  \
# 766  07/2019  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
# 767  11/2018  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
# 768  08/2018  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
# 769  06/2018  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
# 770  02/2018  https://fortress.wa.gov/dshs/adsaapps/lookup/R...
#
#               download_record
# 766  Tue Sep  8 16:43:06 2020
# 767  Tue Sep  8 16:43:08 2020
# 768  Tue Sep  8 16:43:09 2020
# 769  Tue Sep  8 16:43:11 2020
# 770  Tue Sep  8 16:43:12 2020

# %% [markdown]
# Were all the reports in 'df_metadata' actually downloaded?

# %%
# Obtain a list of all the downloaded nursing home PDF enforcement letters
file_list = listdir(download_path)

# Weed out any files in the folder that are not PDFs
file_list = [file for file in file_list if re.search('\.pdf$', file)]
file_list = pd.Series(file_list)

# Is the set of all downloaded PDFs consistent with the list of PDFs in 'df_metadata'?
assert len(file_list) == len(df_metadata)
assert set(file_list) == set(df_metadata['pdf_name'])

# %% [markdown]
# Yes.
#
# Any FAIN IDs in the meta data that were not in the original listing file?

# %%
set(df_metadata['fain_id']).difference(set(df_list['fain_id']))
# Out:
# set()

# %% [markdown]
# Nope. Nothing was created out of nothing.
#
# Any FAIN IDs in the original listing that did not show up in the metadata?

# %%
missing  = set(df_list['fain_id']).difference(set(df_metadata['fain_id']))
missing
# Out:
# {42569,
#  42682,
#  42714,
#  42767,
#  42813,
#  43242,
#  43348,
#  43441,
#  43546,
#  43560,
#  43585,
#  43594,
#  43844,
#  44101,
#  44158,
#  44409,
#  44988,
#  45037,
#  45564,
#  45976,
#  46175,
#  46200}

# %% [markdown]
# So there are cases of nursing homes that were in the original listing and were marked as having reports, but for which  no enforcement letters were downloaded. Let's take a look:

# %%
df_missing = df_list[df_list['fain_id'].isin(missing)]
df_missing
# Out:
#      nf_location_num  nf_loc_region_cde      nf_loc_street_address  \
# 8              15700                  1          1326 Red Apple Rd
# 24             34100                  3         128 BEACON HILL DR
# 38             40260                  2          2720 E Madison St
# 42             40940                  2    100 Timber Ridge Way NW
# 45             23500                  2    7500 SEWARD PARK AVE SO
# 55             10500                  2     805 FRONT STREET SOUTH
# 57             40540                  2  4416 SOUTH BRANDON STREET
# 63             41118                  2          17420 106th Pl SE
# 81             40770                  2      24423 100TH AVENUE SE
# 83             39960                  2        919 109TH AVENUE NE
# 84             40970                  2             715 9TH AVENUE
# 92             40360                  3          2321 NW Schold Pl
# 94             18700                  3        2051 POTTERY AVENUE
# 103            31500                  1                22 W 1ST ST
# 104            16800                  1            100 RIVER PLAZA
# 114            41115                  3           4340 Borgen Blvd
# 140            41119                  2            916 Pacific Ave
# 163            25020                  1       EAST 2903 - 25TH AVE
# 170            40670                  1         151 Buena Vista Dr
# 174            12600                  3  1600 Sleater Kinney Rd SE
# 179            10100                  1             1710 PLAZA WAY
# 197             3500                  1      702 NORTH 16TH AVENUE
#
#       nf_loc_city  nf_loc_zip_cde  nf_loc_phone_num  nf_loc_fax_num  \
# 8       Wenatchee       988013227      5.096823e+09    5.096824e+09
# 24       LONGVIEW       986325859      3.604234e+09    3.606361e+09
# 38        Seattle           98112      2.063225e+09    2.067202e+09
# 42       Issaquah           98027      4.254275e+09    4.254275e+09
# 45        SEATTLE       981180000      2.067259e+09    2.064570e+09
# 55       ISSAQUAH           98027               NaN    4.255576e+09
# 57        SEATTLE       981180000      2.067214e+09    2.067214e+09
# 63         Renton           98055      2.538534e+09    2.538535e+09
# 81           KENT           98030      2.538132e+09    2.538133e+09
# 83       BELLEVUE       980044404      4.256470e+09             NaN
# 84        SEATTLE           98104      2.064072e+09    2.064072e+09
# 92     Silverdale           98383      3.606984e+09    3.606922e+09
# 94   PORT ORCHARD           98366      3.608764e+09    3.608764e+09
# 103      TONASKET           98855      5.094862e+09    5.094863e+09
# 104      BREWSTER           98812      5.096893e+09    5.096893e+09
# 114    Gig Harbor           98332      2.533131e+09    2.532761e+09
# 140       Everett           98201      4.252596e+09             NaN
# 163       SPOKANE       992234963      5.095367e+09    5.095367e+09
# 170      Colville           99114      5.096845e+09    5.096851e+09
# 174         Lacey           98503      3.604560e+09    3.604388e+09
# 179   WALLA WALLA           99362      5.095294e+09    5.095222e+09
# 197        YAKIMA           98902      5.092485e+09    5.094530e+09
#
#             nf_mailing_address nf_mailing_city nf_mailing_state  ...  rcsunit  \
# 8            1326 Red Apple Rd       Wenatchee               WA  ...        D
# 24          128 BEACON HILL DR        LONGVIEW               WA  ...        C
# 38           2720 E Madison St         Seattle               WA  ...        H
# 42     100 Timber Ridge Way NW        Issaquah               WA  ...        F
# 45     7500 SEWARD PARK AVE SO         SEATTLE               WA  ...        F
# 55      805 FRONT STREET SOUTH        ISSAQUAH               WA  ...        F
# 57       4416 SOUTH BRANDON ST         SEATTLE               WA  ...        H
# 63           17420 106th Pl SE          Renton               WA  ...        F
# 81       24423 100TH AVENUE SE            KENT               WA  ...        F
# 83         919 109TH AVENUE NE        BELLEVUE               WA  ...        H
# 84              715 9TH AVENUE         SEATTLE               WA  ...        H
# 92           2321 NW Schold Pl      Silverdale               WA  ...        B
# 94            2051 POTTERY AVE    PORT ORCHARD               WA  ...        B
# 103                22 W 1ST ST        TONASKET               WA  ...        A
# 104            100 RIVER PLAZA        BREWSTER               WA  ...        A
# 114           4340 Borgen Blvd      Gig Harbor               WA  ...        B
# 140               PO Box 13700      Mill Creek               WA  ...        C
# 163    2903 E 25TH AVE STE OFC         SPOKANE               WA  ...        A
# 170         151 Buena Vista Dr        Colville               WA  ...        A
# 174  1600 Sleater Kinney Rd SE           Lacey               WA  ...        C
# 179             1710 PLAZA WAY     WALLA WALLA               WA  ...        D
# 197             702 N 16TH AVE          YAKIMA               WA  ...        D
#
#     total_beds_nf_bed_count  xviii_beds_nf_bed_count  xix_beds_nf_bed_count  \
# 8                        55                      0.0                    0.0
# 24                       67                      NaN                    NaN
# 38                       35                      0.0                   30.0
# 42                       45                     45.0                    0.0
# 45                      205                      0.0                    NaN
# 55                      140                      NaN                    NaN
# 57                      100                      0.0                    NaN
# 63                       60                      0.0                    0.0
# 81                        8                      8.0                    NaN
# 83                       54                     54.0                    NaN
# 84                       34                     34.0                    0.0
# 92                       57                      NaN                    NaN
# 94                       96                      0.0                    0.0
# 103                      42                      0.0                    NaN
# 104                      54                      NaN                    NaN
# 114                      30                     30.0                    0.0
# 140                      31                      0.0                    0.0
# 163                      45                     45.0                    NaN
# 170                      40                      0.0                    NaN
# 174                     155                      0.0                    0.0
# 179                      99                      NaN                    NaN
# 197                     105                      NaN                    NaN
#
#     t1819_beds_nf_bed_count fain_id nf_bed_type_desc has_reports?  \
# 8                      55.0   44158      Title 18/19          Yes
# 24                     67.0   43585      Title 18/19          Yes
# 38                      5.0   43242      Title 18/19          Yes
# 42                      0.0   46200         Title 18          Yes
# 45                    205.0   42813      Title 18/19          Yes
# 55                    140.0   44988      Title 18/19          Yes
# 57                    100.0   43348      Title 18/19          Yes
# 63                     60.0   45037      Title 18/19          Yes
# 81                      NaN   43441         Title 18          Yes
# 83                      NaN   43844         Title 18          Yes
# 84                      0.0   43560         Title 18          Yes
# 92                     47.0   45564      Title 18/19          Yes
# 94                     96.0   42767      Title 18/19          Yes
# 103                    42.0   42569      Title 18/19          Yes
# 104                    54.0   44101      Title 18/19          Yes
# 114                     0.0   44409         Title 18          Yes
# 140                    31.0   46175      Title 18/19          Yes
# 163                     NaN   42682         Title 18          Yes
# 170                    40.0   45976      Title 18/19          Yes
# 174                   155.0   42714      Title 18/19          Yes
# 179                    99.0   43594      Title 18/19          Yes
# 197                   105.0   43546      Title 18/19          Yes
#
#                                       reports_location unnamed:_32
# 8    https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 24   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 38   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 42   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 45   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 55   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 57   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 63   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 81   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 83   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 84   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 92   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 94   https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 103  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 104  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 114  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 140  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 163  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 170  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 174  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 179  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
# 197  https://fortress.wa.gov/dshs/adsaapps/lookup/N...         NaN
#
# [22 rows x 33 columns]

# %% [markdown]
# Upon visual inspection of the links for these cases, we find the reason: Those facilities indeed had reoprts issued on them (inspections, investigations, etc.) but none of those reports were enforcement letters. That explains why they appear in 'df_listing' but don't show up in 'df_metadata'.
#
# The next logical question is: Of the 204 nursing homes that had reports issued to them, how many had enforcement letters?

# %%
print('Out of the', df_list['fain_id'].nunique(), 'nursing homes that had reports issued to them', 
      df_metadata['fain_id'].nunique(), 'had enfrocement letters issued to them.')
# Out:
# Out of the 205 nursing homes that had reports issued to them 183 had enfrocement letters issued to them.
