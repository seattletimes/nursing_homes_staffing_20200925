# %% [markdown]
# # Settings

# %%
import pandas as pd
import numpy as np
from pprint import pprint

# %% [markdown]
# # Original data

# %%
df_orig = pd.read_csv('../output_data/reports_contents/nhf_inspections_contents_perifery.csv')
df = df_orig.copy()

# %%
print('We start with', len(df), 'records. Inisde those records, there are', df['pdf_name'].nunique(), 'unique pdf names.')
# Out:
# We start with 29474 records. Inisde those records, there are 584 unique pdf names.

# %%
df.head()
# Out:
#                                             pdf_name  num_pages  page  \
# 0     ARLINGTON HEALTH AND REHABILITATION YOGA12.pdf          3     1
# 1     ARLINGTON HEALTH AND REHABILITATION YOGA12.pdf          3     2
# 2     ARLINGTON HEALTH AND REHABILITATION YOGA12.pdf          3     3
# 3            AVALON CARE CENTER - PULLMAN COMM11.pdf          1     1
# 4  AVALON HEALTH & REHABILITATION CENTER - PASCO ...          2     1
#
#    num_tables      omb_no provider_id survey_comp_date  \
# 0           0         NaN         NaN              NaN
# 1           0         NaN         NaN              NaN
# 2           1  Washington     WA18800       05/29/2018
# 3           1   0938-0391      505246       09/22/2017
# 4           0         NaN         NaN              NaN
#
#                   provider_name                         provider_address  \
# 0                           NaN                                      NaN
# 1                           NaN                                      NaN
# 2                           NaN                                      NaN
# 3  AVALON CARE CENTER - PULLMAN  NORTHWEST 1310 DEANE, PULLMAN, WA 99163
# 4                           NaN                                      NaN
#
#   form_id event_id facility_id
# 0     NaN      NaN         NaN
# 1     NaN      NaN         NaN
# 2     NaN      NaN         NaN
# 3     NaN      NaN         NaN
# 4     NaN      NaN         NaN

# %%
df.tail()
# Out:
#                                                 pdf_name  num_pages  page  \
# 29469  r willow springs care and rehab survey 4-5-201...         28    24
# 29470  r willow springs care and rehab survey 4-5-201...         28    25
# 29471  r willow springs care and rehab survey 4-5-201...         28    26
# 29472  r willow springs care and rehab survey 4-5-201...         28    27
# 29473  r willow springs care and rehab survey 4-5-201...         28    28
#
#        num_tables omb_no provider_id survey_comp_date provider_name  \
# 29469           0    NaN         NaN              NaN           NaN
# 29470           0    NaN         NaN              NaN           NaN
# 29471           0    NaN         NaN              NaN           NaN
# 29472           0    NaN         NaN              NaN           NaN
# 29473           0    NaN         NaN              NaN           NaN
#
#       provider_address form_id event_id facility_id
# 29469              NaN     NaN      NaN         NaN
# 29470              NaN     NaN      NaN         NaN
# 29471              NaN     NaN      NaN         NaN
# 29472              NaN     NaN      NaN         NaN
# 29473              NaN     NaN      NaN         NaN

# %% [markdown]
# # Reducing

# %% [markdown]
# ### Records with num_tables == 0

# %% [markdown]
# Let's confirm that records where 'num_tables' == 0 are nothing but noise.

# %%
df_noise = df[['omb_no', 'provider_id', 'survey_comp_date', 
               'provider_name', 'provider_address', 'form_id', 'event_id', 'facility_id']]
df_noise = df_noise[df['num_tables']==0]

df_noise.isna().all().all()
# Out:
# True

# %% [markdown]
# Indeed they are. Away with them.

# %%
del(df_noise)
df = df[df['num_tables']>0]

# Consistency test:
# We should now have a unique value for 'num_tables: 1
assert (df['num_tables'] == 1).all()

# %%
print('We now have', len(df), 'records and', df['pdf_name'].nunique(), 'unique pdf names.')
# Out:
# We now have 14417 records and 342 unique pdf names.

# %% [markdown]
# ### Standardizing form_id

# %%
df['form_id'].value_counts(dropna=False)
# Out:
# CMS-2567(02-99)    12641
# NaN                 1004
# 6899                 770
# CMS2567(0299)          2
# Name: form_id, dtype: int64

# %% [markdown]
# It seems obvious there is only one correct form ID: **CMS-2567(02-99)**
#
# There are a couple of cases where all missing are the dashes, so we coorect for that:

# %%
df['form_id'] = df['form_id'].str.replace('CMS2567(0299)', 'CMS-2567(02-99)', regex=False)

# %%
df['form_id'].value_counts(dropna=False)
# Out:
# CMS-2567(02-99)    12643
# NaN                 1004
# 6899                 770
# Name: form_id, dtype: int64

# %% [markdown]
# The cases where the value is **6869** are also incorrect. We deal with them later in the script.

# %%
print('We still have', len(df), 'records and', df['pdf_name'].nunique(), 'unique pdf names.')
# Out:
# We still have 14417 records and 342 unique pdf names.

# %% [markdown]
# ### Records whose only difference is the page number

# %% [markdown]
# Next, we can elimiate all records that, excpet for the page number, are otherwise the same.

# %%
df = df.loc[df.drop(columns=['page']).drop_duplicates().index.tolist(), ]

repeated_pdf_names = df['pdf_name'].value_counts()
repeated_pdf_names = repeated_pdf_names.reset_index()
repeated_pdf_names.columns = ['pdf_name', 'freq']
repeated_pdf_names = repeated_pdf_names[repeated_pdf_names['freq']>1]
repeated_pdf_names = repeated_pdf_names.reset_index(drop=True)

# %%
print('We are left with', len(df), 'records, containing', df['pdf_name'].nunique(), 'unique pdf names, out of which', len(repeated_pdf_names), 'appear more than once.')
# Out:
# We are left with 535 records, containing 342 unique pdf names, out of which 173 appear more than once.

# %% [markdown]
# ### Records where 'omb_no' == 'Washington

# %% [markdown]
# Let's look at the data of some random pdf names to see if we can detect some patterns:

# %%
x = repeated_pdf_names['pdf_name'].sample().tolist()[0]
print(x)
df[df['pdf_name'] == x]
# Out:
# R RIVERSIDE NURSING & REHAB CTR complaint TNPN11 03-13-2019-st.pdf
#                                                 pdf_name  num_pages  page  \
# 17428  R RIVERSIDE NURSING & REHAB CTR complaint TNPN...         50     2
# 17472  R RIVERSIDE NURSING & REHAB CTR complaint TNPN...         50    46
#
#        num_tables      omb_no provider_id survey_comp_date  \
# 17428           1   0938-0391      505358       03/13/2019
# 17472           1  Washington     WA18200       03/13/2019
#
#                        provider_name  \
# 17428  RIVERSIDE NURSING & REHAB CTR
# 17472                            NaN
#
#                                  provider_address          form_id event_id  \
# 17428  1305 ALEXANDER STREET, CENTRALIA, WA 98531  CMS-2567(02-99)   TNPN11
# 17472                                         NaN             6899      NaN
#
#       facility_id
# 17428     WA18200
# 17472         NaN

# %% [markdown]
# It seems likely those records where omb_no == 'Washington' are just noise. Let's confirm:

# %%
df_noise = df[df['omb_no'] == 'Washington']
df_noise[['provider_name', 'provider_address', 'form_id', 'event_id', 'facility_id']].isna().all()
# Out:
# provider_name        True
# provider_address     True
# form_id             False
# event_id             True
# facility_id          True
# dtype: bool

# %% [markdown]
# Except for 'form_id', all fields are full of Nan values. Let's take a look at 'form_id' to se if its non-NaN values are also just noise.

# %%
df_noise['form_id'].value_counts(dropna=False)
# Out:
# 6899    144
# NaN      38
# Name: form_id, dtype: int64

# %% [markdown]
# Indeed. We can do away with them:

# %%
df = df[df['omb_no'] != 'Washington']

del(repeated_pdf_names)
repeated_pdf_names = df['pdf_name'].value_counts()
repeated_pdf_names = repeated_pdf_names.reset_index()
repeated_pdf_names.columns = ['pdf_name', 'freq']
repeated_pdf_names = repeated_pdf_names[repeated_pdf_names['freq']>1]
repeated_pdf_names = repeated_pdf_names.reset_index(drop=True)

# %%
print('We are down to', len(df), 'records and', df['pdf_name'].nunique(), 'unique pdf names, out of which', len(repeated_pdf_names), 'appear more than once.')
# Out:
# We are down to 353 records and 333 unique pdf names, out of which 20 appear more than once.

# %% [markdown]
# ### Repeated PDF names

# %% [markdown]
# Let's see how the df looks for only those repeated pdf names:

# %%
df_repeated = df[df['pdf_name'].isin(repeated_pdf_names['pdf_name'])]
df_repeated
# Out:
#                                                 pdf_name  num_pages  page  \
# 1794   R Aldercrest Health & Rehab Center complaint 0...        115     2
# 1903   R Aldercrest Health & Rehab Center complaint 0...        115   111
# 2493   R Avalon Care Center - Pullman survey L2D611 7...         70     2
# 2560   R Avalon Care Center - Pullman survey L2D611 7...         70    69
# 2563   R Avalon Care Center- Othello LLC PD8D11 Inspe...         49     2
# 2609   R Avalon Care Center- Othello LLC PD8D11 Inspe...         49    48
# 3028   R Avamere Olympia Rehabilitation of Sequim com...         82     2
# 3032   R Avamere Olympia Rehabilitation of Sequim com...         82     6
# 4145   R Bethany at Pacific complaint U3RT11 03-06-20...         93     2
# 4149   R Bethany at Pacific complaint U3RT11 03-06-20...         93     6
# 4578   R CAREAGE OF WHIDBEY complaint 3C1M11 02-14-20...        266     2
# 4584   R CAREAGE OF WHIDBEY complaint 3C1M11 02-14-20...        266     8
# 7609   R FRANKLIN HILLS HEALTH & REHAB CENTER Complai...        107     3
# 7713   R FRANKLIN HILLS HEALTH & REHAB CENTER Complai...        107   107
# 8016   R Forks Community Hospital, LTCU survey L3NT11...         56     1
# 8071   R Forks Community Hospital, LTCU survey L3NT11...         56    56
# 8787   R Gardens on University, The QMKJ11 survey 11-...        121     2
# 8792   R Gardens on University, The QMKJ11 survey 11-...        121     7
# 11530  R Life Care Center of Kennewick complaint 3FLE...         74     2
# 11602  R Life Care Center of Kennewick complaint 3FLE...         74    74
# 12924  R Martha and Mary Health Services complaint 24...        106     2
# 12955  R Martha and Mary Health Services complaint 24...        106    33
# 13115  R McKay Healthcare & Rehab Ctr FIRE 2ERK21 01-...         30     2
# 13116  R McKay Healthcare & Rehab Ctr FIRE 2ERK21 01-...         30     3
# 13249  R Mirabella Seattle complaint JFYP11 12-18-201...         42     2
# 13250  R Mirabella Seattle complaint JFYP11 12-18-201...         42     3
# 13291  R Mission Healthcare at Bellevue complaint TFI...         71     2
# 13292  R Mission Healthcare at Bellevue complaint TFI...         71     3
# 13383  R Montesano Health & Rehabilitation survey 6UT...         49     2
# 13384  R Montesano Health & Rehabilitation survey 6UT...         49     3
# 13460  R Mountain View Rehabilitation and Care Center...        145     2
# 13461  R Mountain View Rehabilitation and Care Center...        145     3
# 13636  R Mt Baker Care Center complaint TEY211 10-31-...         78     2
# 13637  R Mt Baker Care Center complaint TEY211 10-31-...         78     3
# 16401  R Prestige Care & Rehabilitation- Clarkston O0...         43     2
# 16402  R Prestige Care & Rehabilitation- Clarkston O0...         43     3
# 16444  R Prestige Care & Rehabilitation- Parkside UU4...         35     2
# 16445  R Prestige Care & Rehabilitation- Parkside UU4...         35     3
# 17753  R Regency Care Center at Monroe 0D0K12 Inspect...         65     2
# 17765  R Regency Care Center at Monroe 0D0K12 Inspect...         65    14
#
#        num_tables     omb_no provider_id survey_comp_date  \
# 1794            1  0938-0391      505236       09/13/2019
# 1903            1     SURVEY      505236        9/13/2019
# 2493            1  0938-0391      505246       07/27/2018
# 2560            1     SURVEY      505246        7/27/2018
# 2563            1  0938-0391      505255       05/03/2019
# 2609            1     SURVEY      505255         5/3/2019
# 3028            1  0938-0391      505327       12/27/2018
# 3032            1  0938-0391      505327       10/24/2018
# 4145            1  0938-0391      505404       05/01/2019
# 4149            1  0938-0391      505404       03/06/2019
# 4578            1  0938-0391      505309       04/19/2019
# 4584            1  0938-0391      505309       02/14/2019
# 7609            1  0938-0391      505024       12/11/2018
# 7713            1  0938-0391      505024       04/30/2019
# 8016            1  0938-0391      50A174       04/12/2019
# 8071            1  0938-0391      50A174       05/10/2019
# 8787            1  0938-0391      505114       12/31/2018
# 8792            1  0938-0391      505114       11/19/2018
# 11530           1  0938-0391      505080       03/05/2019
# 11602           1  0938-0391      505080       05/16/2019
# 12924           1  0938-0391      505474       09/12/2019
# 12955           1  0938-0391      505474       09/12/2019
# 13115           1  0938-0391      505390       02/21/2019
# 13116           1  0938-0391      505390       01/10/2019
# 13249           1  0938-0391      505520       02/15/2019
# 13250           1  0938-0391      505520       12/18/2018
# 13291           1  0938-0391      505500       03/28/2019
# 13292           1  0938-0391      505500       02/07/2019
# 13383           1  0938-0391      505503       04/30/2019
# 13384           1  0938-0391      505503       03/25/2019
# 13460           1  0938-0391      505407       09/05/2018
# 13461           1  0938-0391      505407       07/09/2018
# 13636           1  0938-0391      505376       12/19/2018
# 13637           1  0938-0391      505376       10/31/2018
# 16401           1  0938-0391      505283       08/07/2019
# 16402           1  0938-0391      505283       06/21/2019
# 16444           1  0938-0391      505401       11/15/2019
# 16445           1  0938-0391      505401       10/10/2019
# 17753           1  0938-0391      505350       11/19/2018
# 17765           1  0938-0391      505350       10/02/2018
#
#                                       provider_name  \
# 1794               ALDERCREST HEALTH & REHAB CENTER
# 1903               ALDERCREST HEALTH & REHAB CENTER
# 2493                   AVALON CARE CENTER - PULLMAN
# 2560                   AVALON CARE CENTER - PULLMAN
# 2563               AVALON CARE CENTER - OTHELLO LLC
# 2609               AVALON CARE CENTER - OTHELLO LLC
# 3028       AVAMERE OLYMPIC REHABILITATION OF SEQUIM
# 3032       AVAMERE OLYMPIC REHABILITATION OF SEQUIM
# 4145                             BETHANY AT PACIFIC
# 4149                             BETHANY AT PACIFIC
# 4578                             CAREAGE OF WHIDBEY
# 4584                             CAREAGE OF WHIDBEY
# 7609           FRANKLIN HILLS HEALTH & REHAB CENTER
# 7713           FRANKLIN HILLS HEALTH & REHAB CENTER
# 8016                 FORKS COMMUNITY HOSPITAL, LTCU
# 8071                 FORKS COMMUNITY HOSPITAL, LTCU
# 8787                     GARDENS ON UNIVERSITY, THE
# 8792                     GARDENS ON UNIVERSITY, THE
# 11530                 LIFE CARE CENTER OF KENNEWICK
# 11602                 LIFE CARE CENTER OF KENNEWICK
# 12924                MARTHA AND MARY HEALTH SERVICE
# 12955                MARTHA AND MARY HEALTH SERVICE
# 13115                  MCKAY HEALTHCARE & REHAB CTR
# 13116                  MCKAY HEALTHCARE & REHAB CTR
# 13249                             MIRABELLA SEATTLE
# 13250                             MIRABELLA SEATTLE
# 13291                MISSION HEALTHCARE AT BELLEVUE
# 13292                MISSION HEALTHCARE AT BELLEVUE
# 13383             MONTESANO HEALTH & REHABILITATION
# 13384             MONTESANO HEALTH & REHABILITATION
# 13460  MOUNTAIN VIEW REHABILITATION AND CARE CENTER
# 13461  MOUNTAIN VIEW REHABILITATION AND CARE CENTER
# 13636                          MT BAKER CARE CENTER
# 13637                          MT BAKER CARE CENTER
# 16401    PRESTIGE CARE & REHABILITATION - CLARKSTON
# 16402    PRESTIGE CARE & REHABILITATION - CLARKSTON
# 16444     PRESTIGE CARE & REHABILITATION - PARKSIDE
# 16445     PRESTIGE CARE & REHABILITATION - PARKSIDE
# 17753                 REGENCY CARE CENTER AT MONROE
# 17765                 REGENCY CARE CENTER AT MONROE
#
#                                         provider_address          form_id  \
# 1794           21400 72ND AVENUE WEST, EDMONDS, WA 98026              NaN
# 1903                 21400 72ND AVENUE WEST, EDMONDS, WA              NaN
# 2493             NORTHWEST 1310 DEANE, PULLMAN, WA 99163  CMS-2567(02-99)
# 2560                   NORTHWEST 1310 DEANE, PULLMAN, WA              NaN
# 2563      495 NORTH THIRTEENTH STREET, OTHELLO, WA 99344  CMS-2567(02-99)
# 2609            495 NORTH THIRTEENTH STREET, OTHELLO, WA              NaN
# 3028             1000 5TH AVENUE SOUTH, SEQUIM, WA 98382  CMS-2567(02-99)
# 3032             1000 5TH AVENUE SOUTH, SEQUIM, WA 98382  CMS-2567(02-99)
# 4145   916 PACIFIC AVENUE 3RD-5TH FLOORS, EVERETT, WA...  CMS-2567(02-99)
# 4149   916 PACIFIC AVENUE 3RD-5TH FLOORS, EVERETT, WA...  CMS-2567(02-99)
# 4578      311 NORTHEAST 3RD STREET, COUPEVILLE, WA 98239  CMS-2567(02-99)
# 4584      311 NORTHEAST 3RD STREET, COUPEVILLE, WA 98239  CMS-2567(02-99)
# 7609            6021 NORTH LIDGERWOOD, SPOKANE, WA 99207  CMS-2567(02-99)
# 7713            6021 NORTH LIDGERWOOD, SPOKANE, WA 99207  CMS-2567(02-99)
# 8016                  530 BOGACHIEL WAY, FORKS, WA 98331  CMS-2567(02-99)
# 8071                  530 BOGACHIEL WAY, FORKS, WA 98331  CMS-2567(02-99)
# 8787              414 S UNIVERSITY RD, SPOKANE, WA 99206  CMS-2567(02-99)
# 8792              414 S UNIVERSITY RD, SPOKANE, WA 99206  CMS-2567(02-99)
# 11530      1508 WEST SEVENTH AVENUE, KENNEWICK, WA 99336  CMS-2567(02-99)
# 11602      1508 WEST SEVENTH AVENUE, KENNEWICK, WA 99336  CMS-2567(02-99)
# 12924    19160 FRONT STREET NORTHEAST, POULSBO, WA 98370  CMS-2567(02-99)
# 12955    19160 FRONT STREET NORTHEAST, POULSBO, WA 98370  CMS-2567(02-99)
# 13115   127 SECOND AVENUE SOUTHWEST, SOAP LAKE, WA 98851  CMS-2567(02-99)
# 13116   127 SECOND AVENUE SOUTHWEST, SOAP LAKE, WA 98851  CMS-2567(02-99)
# 13249           116 FAIRVIEW AVENUE N, SEATTLE, WA 98109  CMS-2567(02-99)
# 13250           116 FAIRVIEW AVENUE N, SEATTLE, WA 98109  CMS-2567(02-99)
# 13291    2424 156TH AVENUE NORTHEAST, BELLEVUE, WA 98007  CMS-2567(02-99)
# 13292    2424 156TH AVENUE NORTHEAST, BELLEVUE, WA 98007  CMS-2567(02-99)
# 13383             800 NORTH MEDCALF, MONTESANO, WA 98563  CMS-2567(02-99)
# 13384             800 NORTH MEDCALF, MONTESANO, WA 98563  CMS-2567(02-99)
# 13460          5925 47TH AVENUE NE, MARYSVILLE, WA 98270  CMS-2567(02-99)
# 13461          5925 47TH AVENUE NE, MARYSVILLE, WA 98270  CMS-2567(02-99)
# 13636         2905 CONNELLY AVENUE, BELLINGHAM, WA 98225  CMS-2567(02-99)
# 13637         2905 CONNELLY AVENUE, BELLINGHAM, WA 98225  CMS-2567(02-99)
# 16401          1242 ELEVENTH STREET, CLARKSTON, WA 99403  CMS-2567(02-99)
# 16402          1242 ELEVENTH STREET, CLARKSTON, WA 99403  CMS-2567(02-99)
# 16444                 308 WEST EMMA, UNION GAP, WA 98903  CMS-2567(02-99)
# 16445                 308 WEST EMMA, UNION GAP, WA 98903  CMS-2567(02-99)
# 17753            1355 WEST MAIN STREET, MONROE, WA 98272  CMS-2567(02-99)
# 17765            1355 WEST MAIN STREET, MONROE, WA 98272  CMS-2567(02-99)
#
#       event_id facility_id
# 1794       NaN         NaN
# 1903       NaN         NaN
# 2493    L2D611     WA21200
# 2560    L2D611         NaN
# 2563    PD8D11     WA19800
# 2609    PD8D11         NaN
# 3028    FI7N12     WA26500
# 3032    FI7N11     WA26500
# 4145    U3RT12     WA02200
# 4149    U3RT11     WA02200
# 4578    3C1M12     WA35040
# 4584    3C1M11     WA35040
# 7609    3YGF11     WA13900
# 7713    3YGF12     WA13900
# 8016    L3NT11     WA31590
# 8071    L3NT12     WA31590
# 8787    QMKJ12     WA15200
# 8792    QMKJ11     WA15200
# 11530   3FLE11     WA20400
# 11602   3FLE12     WA20400
# 12924    24011     WA06100
# 12955   24I011     WA06100
# 13115   2ERK22     WA31300
# 13116   2ERK21     WA31300
# 13249   JFYP12     WA40950
# 13250   JFYP11     WA40950
# 13291   TFI712     WA04580
# 13292   TFI711     WA04580
# 13383   6UTZ12     WA40590
# 13384   6UTZ11     WA40590
# 13460   TDYC12     WA12400
# 13461   TDYC11     WA12400
# 13636   TEY212     WA40270
# 13637   TEY211     WA40270
# 16401   O0I712     WA04400
# 16402   O0I711     WA04400
# 16444   UU4L12     WA03300
# 16445   UU4L11     WA03300
# 17753   0D0K12     WA19000
# 17765   0D0K11     WA19000

# %% [markdown]
# The first that looks clear is that the three records where 'omb_no' == 'SURVEY' are noise.

# %%
df = df[df['omb_no'] != 'SURVEY']

repeated_pdf_names = df['pdf_name'].value_counts()
repeated_pdf_names = repeated_pdf_names.reset_index()
repeated_pdf_names.columns = ['pdf_name', 'freq']
repeated_pdf_names = repeated_pdf_names[repeated_pdf_names['freq']>1]
repeated_pdf_names = repeated_pdf_names.reset_index(drop=True)

# %%
print('We are further down to', len(df), 'records and', df['pdf_name'].nunique(), 'unique pdf names, out of which', len(repeated_pdf_names), 'appear more than once.')
# Out:
# We are further down to 350 records and 333 unique pdf names, out of which 17 appear more than once.

# %%
df.to_csv('../output_data/reports_contents/nhf_inspections_contents_perifery_reduced.csv')
