# %% [markdown]
# # Settings

# %%
import pandas as pd

# %% [markdown]
# # Original data

# %% [markdown]
# Citation frequency report for adult family homes.
#
# Obtained from [Chris Wright](wrighcd2@dshs.wa.gov) on Friday, April 24, 2020 at 1:42 PM

# %%
source_path = '/Volumes/files/COVID19/DSHS_Facility_Reports_Manuel/FAC_1008_Report/'

df_orig = pd.read_excel(source_path + 'Copy of 2020 - 046 - Fac1008_CitationFrequencyAfhBh.xlsx',
                        sheet_name='Fac1008_CitationFrequencyAfhBh', 
                        header=11, usecols=range(0,14), dtype={'Region':str, 'LIC Nmbr':str})

# %%
print(df_orig.shape)
df_orig.dtypes
# Out:
# (12129, 14)
# Region                                  object
# Region-Unit                             object
# Facility                                object
# LIC Nmbr                                object
# Visit Display Id                        object
# Visit Start Date                datetime64[ns]
# Last Date of Data Collection    datetime64[ns]
# Date SOD Sent Out               datetime64[ns]
# Facility Received Date          datetime64[ns]
# Complaint number(s)                     object
# Chapter Description                     object
# Chapter Section                         object
# WRD WACRCWCode                          object
# Deficiency Type                         object
# dtype: object

# %%
df_orig.head()
# Out:
#   Region Region-Unit              Facility LIC Nmbr Visit Display Id  \
# 0   1             1B  ANGELS LANDING NORTH   751471  024-FL-20190307
# 1    NaN         NaN  ANGELS LANDING NORTH   751471  024-FL-20190307
# 2    NaN         NaN  ANGELS LANDING NORTH   751471  024-FL-20190307
# 3    NaN         NaN  ANGELS LANDING NORTH   751471  024-FL-20190307
# 4    NaN         NaN  ANGELS LANDING NORTH   751471  024-FL-20190307
#
#   Visit Start Date Last Date of Data Collection Date SOD Sent Out  \
# 0       2019-03-06                   2019-03-18        2019-03-19
# 1       2019-03-06                   2019-03-18        2019-03-19
# 2       2019-03-06                   2019-03-18        2019-03-19
# 3       2019-03-06                   2019-03-18        2019-03-19
# 4       2019-03-06                   2019-03-18        2019-03-19
#
#   Facility Received Date Complaint number(s)     Chapter Description  \
# 0             2019-03-20                 NaN       Adult family home
# 1             2019-03-20                 NaN            Tuberculosis
# 2             2019-03-20                 NaN            Tuberculosis
# 3             2019-03-20                 NaN         Resident rights
# 4             2019-03-20                 NaN  Safety and maintenance
#
#     Chapter Section        WRD WACRCWCode Deficiency Type
# 0  WAC 388-76-10198    WAC 388-76-10198-4    Citation-POC
# 1  WAC 388-76-10285    WAC 388-76-10285-1    Consultation
# 2  WAC 388-76-10285    WAC 388-76-10285-2    Consultation
# 3  WAC 388-76-10522    WAC 388-76-10522-3    Consultation
# 4  WAC 388-76-10750  WAC 388-76-10750-5-c    Citation-POC

# %%
df_orig.tail()
# Out:
#              Region    Region-Unit                   Facility LIC Nmbr  \
# 12124           NaN            NaN  POLLYS COUNTRY AFH #1 INC    93301
# 12125           NaN            NaN  POLLYS COUNTRY AFH #1 INC    93301
# 12126           NaN            NaN  POLLYS COUNTRY AFH #1 INC    93301
# 12127           NaN  Region Total:                        NaN      NaN
# 12128  State Total:            NaN                        NaN      NaN
#
#       Visit Display Id Visit Start Date Last Date of Data Collection  \
# 12124  035-FL-20190930       2019-09-27                   2019-09-27
# 12125  035-FL-20190930       2019-09-27                   2019-09-27
# 12126  035-FL-20190930       2019-09-27                   2019-09-27
# 12127              NaN              NaT                          NaT
# 12128              NaN              NaT                          NaT
#
#       Date SOD Sent Out Facility Received Date Complaint number(s)  \
# 12124        2019-10-18             2019-10-21                 NaN
# 12125        2019-10-18             2019-10-21                 NaN
# 12126        2019-10-18             2019-10-21                 NaN
# 12127               NaT                    NaT                 NaN
# 12128               NaT                    NaT                 NaN
#
#        Chapter Description   Chapter Section       WRD WACRCWCode  \
# 12124  Medication disposal  WAC 388-76-10490   WAC 388-76-10490-1
# 12125      Resident rights  WAC 388-76-10540     WAC 388-76-10540
# 12126      Resident rights  WAC 388-76-10540   WAC 388-76-10540-4
# 12127                  NaN               NaN  Count of Citations:
# 12128                  NaN               NaN  Count of Citations:
#
#       Deficiency Type
# 12124    Consultation
# 12125    Consultation
# 12126    Consultation
# 12127            3937
# 12128           12125

# %% [markdown]
# # Working data frame

# %%
df = df_orig.copy()

# %%
print(df.shape)
df.tail()
# Out:
# (12129, 14)
#              Region    Region-Unit                   Facility LIC Nmbr  \
# 12124           NaN            NaN  POLLYS COUNTRY AFH #1 INC    93301
# 12125           NaN            NaN  POLLYS COUNTRY AFH #1 INC    93301
# 12126           NaN            NaN  POLLYS COUNTRY AFH #1 INC    93301
# 12127           NaN  Region Total:                        NaN      NaN
# 12128  State Total:            NaN                        NaN      NaN
#
#       Visit Display Id Visit Start Date Last Date of Data Collection  \
# 12124  035-FL-20190930       2019-09-27                   2019-09-27
# 12125  035-FL-20190930       2019-09-27                   2019-09-27
# 12126  035-FL-20190930       2019-09-27                   2019-09-27
# 12127              NaN              NaT                          NaT
# 12128              NaN              NaT                          NaT
#
#       Date SOD Sent Out Facility Received Date Complaint number(s)  \
# 12124        2019-10-18             2019-10-21                 NaN
# 12125        2019-10-18             2019-10-21                 NaN
# 12126        2019-10-18             2019-10-21                 NaN
# 12127               NaT                    NaT                 NaN
# 12128               NaT                    NaT                 NaN
#
#        Chapter Description   Chapter Section       WRD WACRCWCode  \
# 12124  Medication disposal  WAC 388-76-10490   WAC 388-76-10490-1
# 12125      Resident rights  WAC 388-76-10540     WAC 388-76-10540
# 12126      Resident rights  WAC 388-76-10540   WAC 388-76-10540-4
# 12127                  NaN               NaN  Count of Citations:
# 12128                  NaN               NaN  Count of Citations:
#
#       Deficiency Type
# 12124    Consultation
# 12125    Consultation
# 12126    Consultation
# 12127            3937
# 12128           12125

# %%
print(df['Region'].unique())
print(df['Region-Unit'].unique())
# Out:
# ['1   ' nan '2   ' '3   ' 'State Total:']
# ['1B' nan '1C' '1E' 'Region Total:' '2B' '2E' '2G' '2I' '3A' '3D' '3E']

# %%
# Eliminate rows that display subtotals
df = df[df['Region'] != 'State Total:']
df = df[df['Region-Unit'] != 'Region Total:']
df = df.reset_index(drop=True)


# Fill the NaN values of columns 'Region' and 'Region-Unit'
df['Region'] = df['Region'].fillna(method='ffill')
df['Region-Unit'] = df['Region-Unit'].fillna(method='ffill')

# %%
df.head()
# Out:
#   Region Region-Unit              Facility LIC Nmbr Visit Display Id  \
# 0   1             1B  ANGELS LANDING NORTH   751471  024-FL-20190307
# 1   1             1B  ANGELS LANDING NORTH   751471  024-FL-20190307
# 2   1             1B  ANGELS LANDING NORTH   751471  024-FL-20190307
# 3   1             1B  ANGELS LANDING NORTH   751471  024-FL-20190307
# 4   1             1B  ANGELS LANDING NORTH   751471  024-FL-20190307
#
#   Visit Start Date Last Date of Data Collection Date SOD Sent Out  \
# 0       2019-03-06                   2019-03-18        2019-03-19
# 1       2019-03-06                   2019-03-18        2019-03-19
# 2       2019-03-06                   2019-03-18        2019-03-19
# 3       2019-03-06                   2019-03-18        2019-03-19
# 4       2019-03-06                   2019-03-18        2019-03-19
#
#   Facility Received Date Complaint number(s)     Chapter Description  \
# 0             2019-03-20                 NaN       Adult family home
# 1             2019-03-20                 NaN            Tuberculosis
# 2             2019-03-20                 NaN            Tuberculosis
# 3             2019-03-20                 NaN         Resident rights
# 4             2019-03-20                 NaN  Safety and maintenance
#
#     Chapter Section        WRD WACRCWCode Deficiency Type
# 0  WAC 388-76-10198    WAC 388-76-10198-4    Citation-POC
# 1  WAC 388-76-10285    WAC 388-76-10285-1    Consultation
# 2  WAC 388-76-10285    WAC 388-76-10285-2    Consultation
# 3  WAC 388-76-10522    WAC 388-76-10522-3    Consultation
# 4  WAC 388-76-10750  WAC 388-76-10750-5-c    Citation-POC

# %%
df.tail()
# Out:
#       Region Region-Unit                        Facility LIC Nmbr  \
# 12120   3             3E  Queen Esther Adult Family Home   754261
# 12121   3             3E       POLLYS COUNTRY AFH #1 INC    93301
# 12122   3             3E       POLLYS COUNTRY AFH #1 INC    93301
# 12123   3             3E       POLLYS COUNTRY AFH #1 INC    93301
# 12124   3             3E       POLLYS COUNTRY AFH #1 INC    93301
#
#       Visit Display Id Visit Start Date Last Date of Data Collection  \
# 12120  002-CI-20191231       2019-12-30                   2020-01-03
# 12121  035-FL-20190930       2019-09-27                   2019-09-27
# 12122  035-FL-20190930       2019-09-27                   2019-09-27
# 12123  035-FL-20190930       2019-09-27                   2019-09-27
# 12124  035-FL-20190930       2019-09-27                   2019-09-27
#
#       Date SOD Sent Out Facility Received Date Complaint number(s)  \
# 12120        2020-01-08             2020-01-13             3685592
# 12121        2019-10-18             2019-10-21                 NaN
# 12122        2019-10-18             2019-10-21                 NaN
# 12123        2019-10-18             2019-10-21                 NaN
# 12124        2019-10-18             2019-10-21                 NaN
#
#        Chapter Description   Chapter Section      WRD WACRCWCode  \
# 12120      Resident rights  WAC 388-76-10522  WAC 388-76-10522-6
# 12121  Medication disposal  WAC 388-76-10490    WAC 388-76-10490
# 12122  Medication disposal  WAC 388-76-10490  WAC 388-76-10490-1
# 12123      Resident rights  WAC 388-76-10540    WAC 388-76-10540
# 12124      Resident rights  WAC 388-76-10540  WAC 388-76-10540-4
#
#       Deficiency Type
# 12120    Consultation
# 12121    Consultation
# 12122    Consultation
# 12123    Consultation
# 12124    Consultation

# %%
print(df_orig['Visit Start Date'].min())
print(df_orig['Visit Start Date'].max())
# Out:
# 2019-01-02 00:00:00
# 2019-12-31 00:00:00

# %%
print(df_orig['Last Date of Data Collection'].min())
print(df_orig['Last Date of Data Collection'].max())
# Out:
# 2019-01-03 00:00:00
# 2020-12-30 00:00:00

# %%
print(df_orig['Date SOD Sent Out'].min())
print(df_orig['Date SOD Sent Out'].max())
# Out:
# 2019-01-07 00:00:00
# 2020-03-03 00:00:00

# %%
print(df_orig['Facility Received Date'].min())
print(df_orig['Facility Received Date'].max())
# Out:
# 2018-01-14 00:00:00
# 2090-08-22 00:00:00

# %% [markdown]
# TODO: *Facility Received Date* seeems to have dodgy values. Check.

# %% [markdown]
# # Analysis

# %%
print('Between 1/Jan/2019 and 31/Dec/2019, a total of', len(df),'WAC deficiencies were registered in', 
      df['LIC Nmbr'].nunique(), 'licensed adult family organizations. This amounts to an average of',
     len(df)/df['LIC Nmbr'].nunique(),'deficiencies per adult family home.')
# Out:
# Between 1/Jan/2019 and 31/Dec/2019, a total of 12125 WAC deficiencies were registered in 1942 licensed adult family organizations. This amounts to an average of 6.24356333676622 deficiencies per adult family home.

# %%
df['Deficiency Type'].value_counts(dropna=False, normalize=True)
# Out:
# Citation-POC       0.815423
# Consultation       0.174186
# Citation-No POC    0.010392
# Name: Deficiency Type, dtype: float64

# %%
df['Chapter Description'].value_counts(dropna=False, normalize=True).head(30)
# Out:
# Resident rights                                 0.153155
# Negotiated care plan                            0.100948
# Medication                                      0.072742
# Background checks                               0.070598
# Qualifications                                  0.063753
# Medication system                               0.056082
# Adult family home                               0.048000
# Tuberculosis                                    0.047588
# Safety and maintenance                          0.042392
# License annual fee                              0.036289
# Resident record                                 0.036124
# Medical devices                                 0.028948
# Care and services                               0.023340
# Medication storage                              0.018227
# Reporting requirement                           0.017649
# Emergency evacuation drills                     0.012454
# Liability insurance required                    0.011134
# Emergency drinking water supply                 0.011134
# Assessment                                      0.010887
# Fire extinguishers                              0.010392
# Incident log                                    0.009402
# Automatic smoke detectors                       0.008577
# Food services                                   0.007835
# Medication organizers                           0.007423
# Electronic monitoring equipment                 0.005773
# Medication disposal                             0.005773
# Documentation of emergency evacuation drills    0.005443
# Preliminary service plan                        0.005031
# Bedrooms                                        0.004866
# Infection control                               0.004784
# Name: Chapter Description, dtype: float64

# %%
print('Only ', df['Complaint number(s)'].count()/len(df), 'of the total deficiences had a complaint number.')
# Out:
# Only  0.2595463917525773 of the total deficiences had a complaint number.

# %% [markdown]
# **QUESTION**. How should NAs be interpreted in the field 'Complatin number(s)'? Hypothesis:
# - If there is a complaint number, then the violation/deficiency was found by an *inspection*.
# - If there no complaint number, then the violation/deficiency was found by an *investigation*.

# %%
temp = df[['LIC Nmbr', 'Complaint number(s)']].drop_duplicates()
temp = temp.groupby('LIC Nmbr')
temp = temp.count().reset_index().sort_values('Complaint number(s)', ascending=False)
temp = temp.reset_index(drop=True)

# Consistency test
assert temp['Complaint number(s)'].sum() == df['Complaint number(s)'].nunique()

temp.head()
# Out:
#   LIC Nmbr  Complaint number(s)
# 0   554300                    5
# 1   750450                    4
# 2   753474                    4
# 3   690500                    4
# 4   753571                    4

# %%
df['Facility'].value_counts(dropna=False).head(10)
# Out:
# EVELYN B PIPES AFH              99
# Amanda's Senior Home Care       50
# MAPLE PARK ADULT FAMILY HOME    42
# IMNAYS AFH                      41
# OCEAN BREEZE CARE HOME          41
# DALISAY CORSILLES AFH           40
# Dela Cruz AFH                   40
# ROSEMARIE HOLDER AFH            40
# LOVE OUTREACH                   39
# APPLE CREEK                     39
# Name: Facility, dtype: int64
