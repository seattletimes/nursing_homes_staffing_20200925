# %% [markdown]
# # What this script does

# %% [markdown]
# Now that we have obtained the more than 1,000 enforcement letters, we dive into scraping festival using [Jeremy Singer-Vine](https://github.com/jsvine)'s amazing Python package, [PDF Plumber](https://github.com/jsvine/pdfplumber).
#
# As we mentioned before, becasue of their vast number, we did not save them down in this repository, but they are available at the the DSHS's [Nursing Home Facilities Locator](https://fortress.wa.gov/dshs/adsaapps/lookup/NHPubLookup.aspx)

# %% [markdown]
# # SETTINGS

# %%
import pdfplumber
import pandas as pd
from os import listdir
import numpy as np
import re

pd.set_option('display.max_columns', None)

# %% [markdown]
# # LIST OF ENFORCEMENT LETTERS

# %% [markdown]
# We have periodically ran bulk downloads of eforcement letters from the DSHS's [Nursing Home Facilities Locator](https://fortress.wa.gov/dshs/adsaapps/lookup/NHPubLookup.aspx), because the letters posted there change over time. The DSHS explained to us why that is the case:
#
# - On the first of each month an automatic script is ran that purges anything more than three years old and posts new enforcement letters.
# - In addition, when a facility closes down, all its documents automatically purge.
# - Sometimes, older enforcement letters (sometimes from previous years) are not present in the locator website, but will be posted later. Those older letters may be from nursing homes that had been going through a change of ownership. In that scenario, there would be a time where the locator would have no documents because the facility’s state license is officially “closed” (So all documents automatically purge). NH are the one facility type where even when they change ownership they still “own” their previous owners enforcement record. So the letters get reposted under the new licensee. There may be a delay between the reposting since that must be done manually.
#
# As a result, each bulk download will contain duplicated letters from previous downloads.
#
# Here we create a list of unique letters across all downloads:

# %%
path = '/Volumes/files/COVID19/Manuel_RCF_Data/State_DSHS/ALTSA_reports/'
folders = ['NH_enforcement_letters_2020-03/',
           'NH_enforcement_letters_2020-06-09/',
           'NH_enforcement_letters_2020-06-24/',
           'NH_enforcement_letters_2020-07-16/',
           'NH_enforcement_letters_2020-08-20/',
           'NH_enforcement_letters_2020-09-08/',
           'NH_2020_Jan-Feb/individual_letters/']

# %%
d = {}
for i in range(len(folders)):
    d['{0}'.format(i)] = listdir(path + folders[i])

d2 = {}
for key, pdf_list in d.items():
    d2['{0}'.format(key)] = pd.DataFrame(pdf_list, columns=['pdf_name'])
    d2['{0}'.format(key)]['folder'] = folders[int(key)]

df_letters = pd.DataFrame()
for key, df in d2.items():
    print(key, df.shape)
    df_letters = pd.concat([df_letters, df])

df_letters = df_letters.drop_duplicates(subset=['pdf_name'], keep='first')
df_letters = df_letters.reset_index(drop=True)
# Out:
# 0 (859, 2)
# 1 (826, 2)
# 2 (834, 2)
# 3 (792, 2)
# 4 (785, 2)
# 5 (771, 2)
# 6 (61, 2)

# %%
df_letters
# Out:
#                                                pdf_name  \
# 0            Advance Post Acute (G, CMP, CF) 4 6 18.pdf
# 1     Alaska Gardens (FP, Hx G, prior E, CMP, CF) 12...
# 2                Alaska Gardens (Hx D prior E) 7 16.pdf
# 3              Alaska Gardens (Hx F prior D) 8 9 18.pdf
# 4           Alaska Gardens (Hx G, prior E) 11 16 18.pdf
# ...                                                 ...
# 1030  Warm_Beach_Care_Center_February_21_2017_letter...
# 1031  Washington_Veterans_Home_-_Retsil_February_10_...
# 1032  Willapa_Harbor_Health_and_Rehab_February_13_20...
# 1033  Willapa_Harbor_Health_and_Rehab_February_14_20...
# 1034  Willapa_Harbor_Health_and_Rehab_February_3_201...
#
#                                    folder
# 0         NH_enforcement_letters_2020-03/
# 1         NH_enforcement_letters_2020-03/
# 2         NH_enforcement_letters_2020-03/
# 3         NH_enforcement_letters_2020-03/
# 4         NH_enforcement_letters_2020-03/
# ...                                   ...
# 1030  NH_2020_Jan-Feb/individual_letters/
# 1031  NH_2020_Jan-Feb/individual_letters/
# 1032  NH_2020_Jan-Feb/individual_letters/
# 1033  NH_2020_Jan-Feb/individual_letters/
# 1034  NH_2020_Jan-Feb/individual_letters/
#
# [1035 rows x 2 columns]

# %% [markdown]
# So we have got ourselves over a thousand PDF files—most of them with several pages—to scrape. Shall we?

# %% [markdown]
# # SCRAPING FEST

# %% [markdown]
# ### The loooooooooop

# %%
# Create the dataframe where all the data will be deposited.
df_all_reports = pd.DataFrame(columns = ['pdf_name', 'letter_date', 
                                         'survey_date', 'survey_type',
                                         'vendor_num', 'fed_num', 'aem_num', 'action', 
                                         'page', 'image_based',
                                         'fed_enforcement', 'nc_hist','epoc', 'state_rem', 'appeal_rights',
                                         'find_code', 'find_desc', 
                                         'wac', 'cmp_item', 'cmp_total'])

print('idx|pgs|rows|pdf_name')

# For each enforcement letter:
for index, row in df_letters.iterrows(): 

    pdf = pdfplumber.open(path + row['folder'] + row['pdf_name'])
    print(index, '|', len(pdf.pages), '|', len(df_all_reports), '|', row['pdf_name'])
    
    # As we scrap each page, we will save the data we extract from them in these dataframes:
    df_cmps = pd.DataFrame(columns = ['page', 'wac', 'cmp_item', 'cmp_total'])
    df_sections = pd.DataFrame(columns = ['page','fed_enforcement', 'nc_hist', 'epoc', 'state_rem', 'appeal_rights'])
    df_finds = pd.DataFrame(columns = ['page','find_code', 'find_desc'])

    
    # For each page in the report:
    for pg in pdf.pages:
        
        # Exctract all the text in the page into a single variable
        pg_txt = pg.extract_text()
        
        if not pg_txt:
            new_record = {'pdf_name':row['pdf_name'],
                          'letter_date':np.nan,
                          'vendor_num':np.nan, 
                          'fed_num':np.nan, 
                          'aem_num':np.nan, 
                          'action':np.nan, 
                          'survey_date':np.nan, 
                          'survey_type':np.nan,
                          'page':pg.page_number,
                          'image_based':True,
                          'fed_enforcement':np.nan,
                          'nc_hist':np.nan,
                          'epoc':np.nan,
                          'state_rem':np.nan,
                          'appeal_rights':np.nan,
                          'find_code':np.nan,
                          'find_desc':np.nan,
                          'wac':np.nan, 
                          'cmp_item':np.nan,
                          'cmp_total':np.nan}
            df_all_reports = df_all_reports.append(new_record, ignore_index=True)

        else:

            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            # REPORT METADATA: 'letter_date, 'vendor_num', 'fed_num', 'aem_num', 'action'
            # (These 5 data pieces are always on page 1)
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            
            if pg.page_number == 1:

                # ~~~~~ Data found on top area: 'letter_date, 'vendor_num', 'fed_num', 'aem_num'

                top_area = pg.crop((pg.bbox[0], pg.bbox[1],
                                     pg.bbox[2], pg.bbox[3]/3))
                top_lines = top_area.extract_text().split('\n')

                # 'letter_date'
                try:
                    pattern = '^[A-Za-z]+\s?\d{1,2},\s?\d{4}'
                    letter_date = [line for line in top_lines if re.match(pattern, line.strip())]
                    letter_date = letter_date[0]
                    del(pattern)
                except:
                    letter_date = np.nan

                # 'vendor_num', 'fed_num', 'aem_num',
                id_lines = [line for line in top_lines if re.match('^Vendor|AEM', line.strip())]
                # Some times these data points are absent. For those cases:
                if not id_lines: 
                    vendor_num = np.nan
                    fed_num = np.nan
                    aem_num = np.nan
                # If we do find the data points:
                else: 
                    # Vendor number
                    try:
                        vendor_num = id_lines[0].split('/')[0].strip()
                        vendor_num = vendor_num.split(':')[-1].strip()
                    except:
                        vendor_num = np.nan
                    # Fed number
                    try:
                        fed_num = id_lines[0].split('/')[1].strip()
                        fed_num = fed_num.split(':')[-1].strip()
                    except:
                        fed_num = np.nan
                    # AEM number
                    try:
                        aem_num = id_lines[1].split('#')[-1].strip()
                    except:
                        aem_num = np.nan


                # ~~~~~ Data found on middle area: 'action'

                middle_area = pg.crop((pg.bbox[0], pg.bbox[3]/3,
                                       pg.bbox[2], pg.bbox[3]*2/3))
                middle_lines = middle_area.extract_text().split('\n')
                middle_lines = [line.strip() for line in middle_lines]
                middle_lines = [line for line in middle_lines if re.match('^[A-Z,\s]+$', line)]
                if middle_lines:
                    action = ' '.join(middle_lines)
                else:
                    action = np.nan

                    
                    
                # ~~~~~ 'survey_date' and 'survey_type'
                
                try:
                    survey_txt = re.search('(On.*conducted an? .* at your facility)', pg_txt.replace('\n','')).group(1)
                    # There may have been more than one instance of the key phrase 'at your facility'.
                    # Get just the first instance
                    survey_txt = survey_txt.split('at your facility')[0]

                    rgx = '((january|february|march|april|may|june|july|august|september|october|november|december)\s\d{1,2},?\s\d{4})'
                    survey_date = re.search(rgx, survey_txt.lower()).group(1)

                    rgx = 'conducted an? (.*)'
                    survey_type = re.search(rgx, survey_txt.lower()).group(1)

                except:
                    survey_txt = np.nan
                    survey_date = np.nan
                    survey_type = np.nan

                    
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            # DETAILED DATA: Findings, federal enforcement, ePOC and fines
            # (These data points can show up in any page, not just in page 1)
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

            
            # ~~~~~ Findings: 'find_code', 'find_desc'
            
            # Split the pate's text using a first parenthesis as the mark
            finds_list = pg_txt.split('(')
            # Reduce the created list to only the elements that start with this pattern: CAPITAL);
            finds_list = [f for f in finds_list  if re.match('^[A-Z]\);', f)]
            if not finds_list:
                find_code = np.nan
                find_desc = np.nan
            else:
                # Select only the first find (If there are >1, probably from non-compliance history)
                find = finds_list[0]
                # Get rid of all text after the first period.
                find = find.split('.')
                find = find[0]
                # Eliminate noise characters
                find = find.replace(')', '').replace('\n', '') 
                # Split using ';'
                find = find.split(';')
                # The first element of the new list is the finding code
                find_code = find[0].strip()
                # The second element of the new list is the finding description
                find_desc = find[1].strip()
                    
            find_record = {'page':pg.page_number,
                           'find_code':find_code,
                           'find_desc':find_desc}
            df_finds = df_finds.append(find_record, ignore_index=True)


            
            # ~~~~~ Sections
            # - Federal enforcement
            # - Electronic Plan of Correction (ePOC)
            # - Non-compliance history
            # - Appeal Rights

            # For sections + fines, we will split the page text into lines using '\n':
            pg_lines = pg_txt.split('\n')
            pg_lines = [line.strip() for line in pg_lines]
         
            # For each section, determine if there is a line that indicates its presence in the report
            fed_lines = [line for line in pg_lines if re.search('Federal Enforcement', line)]
            epoc_lines = [line for line in pg_lines if re.search('Electronic Plan of Correction \(ePOC\)', line)]
            history_lines = [line for line in pg_lines if re.search('History of Non-Compliance', line)]
            remedy_lines = [line for line in pg_lines if re.search('State Remedies', line)]
            appeal_lines = [line for line in pg_lines if re.search('Appeal Rights', line)]
            
            # Create a record for federal enforcement, nc history & epoc:
            sections_record = {'page':pg.page_number,
                               'fed_enforcement':len(fed_lines)>0,
                               'nc_hist':len(history_lines)>0,
                               'epoc':len(epoc_lines)>0,
                               'state_rem':len(remedy_lines)>0,
                               'appeal_rights':len(appeal_lines)>0
                              }
            df_sections = df_sections.append(sections_record, ignore_index=True)

            
            # ~~~~~ Fines: 'wac', 'cmp_item', 'cmp_total'
            
            # Look for any lines that contain a $ sign
            dollar_lines = [line for line in pg_lines if re.search('\$', line)]                        

            # We now want to divide 'dollar_lines' list into two lists:
            # 1- A list with only one line: the line that contains the aggregated amount of all fines
            # 2- A list iwth all the lines that contain individual WAC fines
            
            # 1- Line that contain the aggregate fined amount
            cmp_total_line = [line for line in dollar_lines if re.search('check', line)]
            if not cmp_total_line:
                cmp_total = np.nan
            else:
                # This list should only have one element, since there should only be 
                # one line with the total amount mulcted. Lets test for that:
                assert len(cmp_total_line) == 1
                try:
                    pattern = '\$((\d+(,\s?|\.)?)+\d+)'
                    cmp_total = re.search(pattern, cmp_total_line[0]).group(1)
                    del(pattern)
                except:
                    cmp_total = np.nan

            # 2- Lines that contain individual WAC fines
            # Subset of those dollar_lines that START with a wac code
            cmp_item_lines = [line for line in dollar_lines if re.search('^(WAC\s?)?\d+-\d+-\s?\d+', line)]

            # If there are no lines with $ signs and WAC codes
            if not cmp_item_lines:
                wac = np.nan
                cmp_item = np.nan
                
                cmp_record = {'page':pg.page_number,
                                 'wac':wac,
                                 'cmp_item':cmp_item,
                                 'cmp_total':cmp_total}
                df_cmps = df_cmps.append(cmp_record, ignore_index=True)
            # And if there are
            else:
                for line in cmp_item_lines:
                    # WAC code (Notice that here we don't require it to be at the beginnig)
                    pattern = '((WAC\s?)?\d+-\d+-\s?\d+\s?(\(([0-9]|[a-z])\)\s?)*)'
                    wac = re.search(pattern, line).group(1)
                    del(pattern)
                    # CMP
                    pattern = '\$((\d+(,|\.)?)+\d+)'
                    cmp_item = re.search(pattern, line).group(1)
                    del(pattern)

                    cmp_record = {'page':pg.page_number,
                                     'wac':wac,
                                     'cmp_item':cmp_item,
                                     'cmp_total':cmp_total}
                    df_cmps = df_cmps.append(cmp_record, ignore_index=True)

                    
    # Consolidate df_finds, df_cmps & df_sections into a single data frame: df_one_report
    df_one_report = df_finds.join(df_cmps.set_index('page'), on='page', how='outer').reset_index(drop=True)
    df_one_report = df_one_report.join(df_sections.set_index('page'), on='page', how='outer').reset_index(drop=True)

    # Add the report-wide data to df_one_report
    df_one_report['pdf_name'] = row['pdf_name']
    df_one_report['letter_date'] = letter_date
    df_one_report['survey_date'] = survey_date
    df_one_report['survey_type'] = survey_type
    df_one_report['vendor_num'] = vendor_num
    df_one_report['fed_num'] = fed_num
    df_one_report['aem_num'] = aem_num
    df_one_report['action'] = action
    df_one_report['image_based'] = False
    
    # Rearrange columns according to the column order of 'df_all_reports' data frame
    df_one_report = df_one_report[df_all_reports.columns]

    # Attach 'df_one_report' to 'df_all_reports'
    df_all_reports = df_all_reports.append(df_one_report, ignore_index=True)
    del(df_one_report)
# Out:
# idx|pgs|rows|pdf_name
# 0 | 5 | 0 | Advance Post Acute (G, CMP, CF) 4 6 18.pdf
# 1 | 5 | 5 | Alaska Gardens (FP, Hx G, prior E, CMP, CF) 12 19 18.pdf
# 2 | 4 | 12 | Alaska Gardens (Hx D prior E) 7 16.pdf
# 3 | 4 | 16 | Alaska Gardens (Hx F prior D) 8 9 18.pdf
# 4 | 5 | 20 | Alaska Gardens (Hx G, prior E) 11 16 18.pdf
# 5 | 6 | 26 | Alaska Gardens (K, HX Prior Fg, Prior G, Prior D, SUB, SP, CMP, CF) 1 17 19.pdf
# 6 | 1 | 34 | Alaska Gardens (Lift SP, BIC) 2 14 19.pdf
# 7 | 5 | 35 | Alaska Gardens (OSFM IJ, R, G, CMP, CF) 4 4 19.pdf
# 8 | 5 | 41 | Alaska Gardens Health (G, CMP, CF) 2 20 18.pdf
# 9 | 4 | 46 | Aldercrest ( 2nd Hx GG, prior G, prior D) 5 2 19.pdf
# 10 | 4 | 50 | Aldercrest (Failed Post, prior GG, CMP, CF) 7 19 18.pdf
# 11 | 5 | 54 | Aldercrest (GG, CMP, CF) 8 17.pdf
# 12 | 5 | 61 | Aldercrest (Hx GG, CMP, CF, prior D) 3 20 19.pdf
# 13 | 5 | 67 | Aldercrest (Hx GG, CMP, CF, prior D) 4 25 18.pdf
# 14 | 5 | 72 | Aldercrest (Hx GG, CMP, CF, prior G, prior D) 6 15 18.pdf
# 15 | 4 | 77 | Aldercrest Health & Rehab (GG, CMP, CF) 7 19 18.pdf
# 16 | 5 | 81 | Aldercrest Health (GG, CMP, CF) 1 17 18.pdf
# 17 | 4 | 86 | Aldercrest Health and Rehab Center (GG, CMP, CF) 8 15 19.pdf
# 18 | 5 | 91 | Alderwood Manor (G, CMP, CF) 7 17.pdf
# 19 | 4 | 96 | Alderwood Manor (GG, CMP, CF) 8 10 18.pdf
# 20 | 4 | 100 | Alderwood Manor (Hx D prior D) 4 17 19.pdf
# 21 | 4 | 104 | Alderwood Manor (Hx D prior D) 6 17.pdf
# 22 | 4 | 108 | Alderwood Manor (Hx G prior G CMP CF) 8 17.pdf
# 23 | 5 | 112 | Alderwood Park (3OOC, Hx D prior Failed Post, CI, IJ R, SUB, Cont SP, Cond, CF, CMP) 3 26 18.pdf
# 24 | 1 | 117 | Alderwood Park (BIC - Lift SP) 5 9 18 .pdf
# 1021 | 6 | 4875 | Shuksan_Healthcare_Center_March_8_2017_letter_47.pdf
# 1022 | 4 | 4885 | Tekoa_Care_Center_January_13_2017_letter_49.pdf
# 1023 | 4 | 4889 | Tekoa_Care_Center_January_13_2017_letter_50.pdf
# 1024 | 5 | 4893 | The_Springs_at_Pacific_Regent_February_9_2017_letter_48.pdf
# 1025 | 4 | 4898 | Toppenish_Nursing_and_Rehab_Center_February_13_2017_letter_51.pdf
# 1026 | 4 | 4902 | Toppenish_Nursing_and_Rehab_Center_February_27_2017_letter_52.pdf
# 1027 | 5 | 4906 | University_Place_Care_Center_February_17_2017_letter_54.pdf
# 1028 | 5 | 4912 | University_Place_Care_Center_January_30_2017_letter_53.pdf
# 1029 | 4 | 4918 | Warm_Beach_Care_Center_December_30_2016_letter_57.pdf
# 1030 | 6 | 4922 | Warm_Beach_Care_Center_February_21_2017_letter_56.pdf
# 1031 | 4 | 4932 | Washington_Veterans_Home_-_Retsil_February_10_2017_letter_55.pdf
# 1032 | 7 | 4936 | Willapa_Harbor_Health_and_Rehab_February_13_2017_letter_58.pdf
# 1033 | 2 | 4946 | Willapa_Harbor_Health_and_Rehab_February_14_2017_last_letter.pdf
# 1034 | 6 | 4948 | Willapa_Harbor_Health_and_Rehab_February_3_2017_letter_59.pdf

# %% [markdown]
# Let's take a look at our freshly baked dataset.

# %%
print(df_all_reports.shape)
print(df_all_reports.nunique())

df_all_reports
# Out:
# (4958, 20)
# pdf_name           1035
# letter_date         580
# survey_date         581
# survey_type         111
# vendor_num          248
# fed_num             217
# aem_num             701
# action               56
# page                  8
# image_based           2
# fed_enforcement       2
# nc_hist               2
# epoc                  2
# state_rem             2
# appeal_rights         2
# find_code             9
# find_desc            50
# wac                 178
# cmp_item             41
# cmp_total            66
# dtype: int64
#                                                pdf_name        letter_date  \
# 0            Advance Post Acute (G, CMP, CF) 4 6 18.pdf    April 12, 2018
# 1            Advance Post Acute (G, CMP, CF) 4 6 18.pdf    April 12, 2018
# 2            Advance Post Acute (G, CMP, CF) 4 6 18.pdf    April 12, 2018
# 3            Advance Post Acute (G, CMP, CF) 4 6 18.pdf    April 12, 2018
# 4            Advance Post Acute (G, CMP, CF) 4 6 18.pdf    April 12, 2018
# ...                                                 ...                ...
# 4953  Willapa_Harbor_Health_and_Rehab_February_3_201...  February 3, 2017
# 4954  Willapa_Harbor_Health_and_Rehab_February_3_201...  February 3, 2017
# 4955  Willapa_Harbor_Health_and_Rehab_February_3_201...  February 3, 2017
# 4956  Willapa_Harbor_Health_and_Rehab_February_3_201...  February 3, 2017
# 4957  Willapa_Harbor_Health_and_Rehab_February_3_201...  February 3, 2017
#
#            survey_date                                        survey_type  \
# 0        april 6, 2018               unannounced complaint investigation
# 1        april 6, 2018               unannounced complaint investigation
# 2        april 6, 2018               unannounced complaint investigation
# 3        april 6, 2018               unannounced complaint investigation
# 4        april 6, 2018               unannounced complaint investigation
# ...                ...                                                ...
# 4953  january 31, 2017  complaint investigation and partial extended s...
# 4954  january 31, 2017  complaint investigation and partial extended s...
# 4955  january 31, 2017  complaint investigation and partial extended s...
# 4956  january 31, 2017  complaint investigation and partial extended s...
# 4957  january 31, 2017  complaint investigation and partial extended s...
#
#      vendor_num fed_num aem_num                     action page image_based  \
# 0       4115441  505355  WADC9Q  IMPOSITION OF CIVIL FINES    1       False
# 1       4115441  505355  WADC9Q  IMPOSITION OF CIVIL FINES    2       False
# 2       4115441  505355  WADC9Q  IMPOSITION OF CIVIL FINES    3       False
# 3       4115441  505355  WADC9Q  IMPOSITION OF CIVIL FINES    4       False
# 4       4115441  505355  WADC9Q  IMPOSITION OF CIVIL FINES    5       False
# ...         ...     ...     ...                        ...  ...         ...
# 4953    4113577  505349  WA6PHJ                        NaN    4       False
# 4954    4113577  505349  WA6PHJ                        NaN    4       False
# 4955    4113577  505349  WA6PHJ                        NaN    4       False
# 4956    4113577  505349  WA6PHJ                        NaN    5       False
# 4957    4113577  505349  WA6PHJ                        NaN    6       False
#
#      fed_enforcement nc_hist   epoc state_rem appeal_rights find_code  \
# 0              False   False   True     False         False         G
# 1              False   False  False      True         False       NaN
# 2              False   False  False     False          True       NaN
# 3              False   False  False     False         False       NaN
# 4              False   False  False     False         False       NaN
# ...              ...     ...    ...       ...           ...       ...
# 4953           False   False  False     False          True       NaN
# 4954           False   False  False     False          True       NaN
# 4955           False   False  False     False          True       NaN
# 4956           False   False  False     False         False       NaN
# 4957           False   False  False     False         False       NaN
#
#                                               find_desc  \
# 0     isolated deficiencies that constitute actual h...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4953                                                NaN
# 4954                                                NaN
# 4955                                                NaN
# 4956                                                NaN
# 4957                                                NaN
#
#                             wac  cmp_item  cmp_total
# 0                           NaN       NaN        NaN
# 1       WAC 388-97- 1060(3)(g)   1,000.00        NaN
# 2                           NaN       NaN        NaN
# 3                           NaN       NaN   1,000.00
# 4                           NaN       NaN        NaN
# ...                         ...       ...        ...
# 4953  WAC 388-97-0640(2)(a)(b)   3,000.00        NaN
# 4954     WAC 388-97-1060(3)(b)   1,000.00        NaN
# 4955        WAC 388-97-1620(1)   3,000.00        NaN
# 4956                        NaN       NaN  13,000.00
# 4957                        NaN       NaN        NaN
#
# [4958 rows x 20 columns]

# %% [markdown]
# # CLEANING THE SCRAPED DATA

# %%
df = df_all_reports.copy()

# %% [markdown]
# ## WAC codes

# %% [markdown]
# The first clean version of the code will include:
# - Title
# - Chapter
# - Section
# - Subsection

# %%
df['wac_clean_long'] = df['wac'].str.replace('WAC|\s', '') # Don't need spaces, nor to be reminded they are *WAC* codes.
df['wac_clean_long'] = df['wac_clean_long'].str.strip()
df['wac_clean_long'] = df['wac_clean_long'].str.replace('97-97-', '97-')
df['wac_clean_long'] = df['wac_clean_long'].str.replace('\\', '') # Only one case we could see with '\'

# %% [markdown]
# Create shorter version of the code, one that will not include the subsection.

# %%
df['wac_clean_short'] = df['wac_clean_long'].str.extract('(\d+-\d+-\d+)')

# %% [markdown]
# ## Civil moneray penalties

# %% [markdown]
# We transform *cmp_item* and *cmp_total* into numeric type variables

# %%
# Individual cmp
df['cmp_item_num'] = df['cmp_item'].str.strip().str.replace(',|\s', '')
df['cmp_item_num'] = df['cmp_item_num'].str.replace('1.500.00', '1500.00') # Just one case
df['cmp_item_num'] = pd.to_numeric(df['cmp_item_num'])

# Aggregate cmp
df['cmp_total_num'] = df['cmp_total'].str.strip().str.replace(',|\s', '')
df['cmp_total_num'] = pd.to_numeric(df['cmp_total_num'])

print('Total fines (from adding individual WAC fines of each report) =', df['cmp_item_num'].sum(skipna=True))
print('Total fines (from adding only the aggregate fine of each report) =', df['cmp_total_num'].sum(skipna=True))
print('So we have a slight discrepancy of', 
      df['cmp_total_num'].sum(skipna=True) - df['cmp_item_num'].sum(skipna=True))
# Out:
# Total fines (from adding individual WAC fines of each report) = 2560968.52
# Total fines (from adding only the aggregate fine of each report) = 2645518.52
# So we have a slight discrepancy of 84550.0

# %% [markdown]
# ## Letter dates

# %% [markdown]
# We transform *letter_date* into a date-type variable

# %%
# Consistecy test: Does each enforcement letter have only one report date?
temp = df[['pdf_name', 'letter_date']]
temp = temp.drop_duplicates().reset_index(drop=True)
assert len(temp) == df['pdf_name'].nunique()

del(temp)

# %%
df['letter_dt'] = pd.to_datetime(df['letter_date'])

# %% [markdown]
# **Consistency test**: What are the oldest and earliest dates?

# %%
print(df['letter_dt'].min())
print(df['letter_dt'].max())
# Out:
# 2016-12-30 00:00:00
# 2108-05-15 00:00:00

# %% [markdown]
# Turns out the earliest date is almost a century in the future. Obviously there must be something wrong with some years. Let's look for them.

# %%
df['letter_dt'].dt.year.value_counts(dropna=False)
# Out:
# 2017.0    1630
# 2019.0    1560
# 2018.0    1168
# 2020.0     555
# NaN         33
# 2108.0       4
# 2107.0       4
# 2016.0       4
# Name: letter_dt, dtype: int64

# %%
df[df['letter_date'].str.contains('2108|2107', na=False)]['pdf_name'].unique()
# Out:
# array(['Garden Village (Hx E prior F) 6 17.pdf',
#        'Olympia Transitional Care (GG, CMP, CF) 5 1 18.pdf'], dtype=object)

# %% [markdown]
# A visual review of those two PDF reports confirms our theory. We correct for that typo.

# %%
df = df.drop(['letter_dt'], axis=1)

df['letter_dt'] = df['letter_date'].str.replace('2107', '2017').str.replace('2108', '2018')
df['letter_dt'] = pd.to_datetime(df['letter_dt'])

# %%
df['letter_dt'].dt.year.value_counts(dropna=False)
# Out:
# 2017.0    1634
# 2019.0    1560
# 2018.0    1172
# 2020.0     555
# NaN         33
# 2016.0       4
# Name: letter_dt, dtype: int64

# %%
print(df['letter_dt'].min())
print(df['letter_dt'].max())
# Out:
# 2016-12-30 00:00:00
# 2020-08-28 00:00:00

# %% [markdown]
# ## Survey dates

# %% [markdown]
# We transform *survey_date* into a date type variable

# %%
# Consistecy test: Does each enforcement letter have only one report date?
temp = df[['pdf_name', 'survey_date']]
temp = temp.drop_duplicates().reset_index(drop=True)
assert len(temp) == df['pdf_name'].nunique()

del(temp)

# %%
df['survey_dt'] = pd.to_datetime(df['survey_date'])

# %%
df['survey_date'].value_counts(dropna=False)
# Out:
# NaN                  165
# february 24, 2017     50
# may 25, 2017          36
# february 21, 2019     28
# february 21, 2017     28
#                     ...
# july 17, 2016          3
# october 18, 2019       2
# may 30, 2018           2
# may 10, 2017           2
# september 2, 2016      2
# Name: survey_date, Length: 582, dtype: int64

# %%
df['survey_dt'].value_counts(dropna=False)
# Out:
# NaT           165
# 2017-02-24     50
# 2017-05-25     36
# 2019-02-21     28
# 2017-02-21     28
#              ...
# 2018-11-13      3
# 2018-05-30      2
# 2019-10-18      2
# 2017-05-10      2
# 2016-09-02      2
# Name: survey_dt, Length: 582, dtype: int64

# %% [markdown]
# **Consistency test**: What are the oldest and earliest dates?

# %%
print(df['survey_dt'].min())
print(df['survey_dt'].max())
# Out:
# 2016-01-20 00:00:00
# 2109-01-17 00:00:00

# %% [markdown]
# Turns out the earliest date is almost a century in the future. Obviously there must be something wrong with some years. Let's look for them.

# %%
df['survey_dt'].dt.year.value_counts(dropna=False)
# Out:
# 2017.0    1572
# 2019.0    1507
# 2018.0    1130
# 2020.0     520
# NaN        165
# 2016.0      35
# 2107.0      16
# 2109.0       8
# 2108.0       5
# Name: survey_dt, dtype: int64

# %%
df[df['survey_date'].str.contains('2107|2108|2109', na=False)]['pdf_name'].unique()
# Out:
# array(['Alaska Gardens (K, HX Prior Fg, Prior G, Prior D, SUB, SP, CMP, CF) 1 17 19.pdf',
#        'Franklin Hills Health and Rehab (GG, CMP, CF) 3 16.pdf',
#        'Grays Harbor (GG, CMP, CF) 3 17.pdf',
#        'Prestige Care - Sunnyside (G, CMP, CF) 1 3 18.pdf',
#        'Richland Rehab (D prior D, CMP) 10 18 17.pdf',
#        'Grays_Harbor_Health_and_Rehabilitation_Center_March_6_2017_letter_13.pdf'],
#       dtype=object)

# %% [markdown]
# A visual inspection of those letters shows that indeed these are typos, and consist in having the position of the '1' and the '0' in the year flipped. We correct for that now.

# %%
df = df.drop('survey_dt', axis=1)

df['survey_dt'] = df['survey_date'].str.replace('2107','2017').str.replace('2108','2018').str.replace('2109','2019')
df['survey_dt'] = pd.to_datetime(df['survey_dt'])

# %%
df['survey_dt'].dt.year.value_counts(dropna=False)
# Out:
# 2017.0    1588
# 2019.0    1515
# 2018.0    1135
# 2020.0     520
# NaN        165
# 2016.0      35
# Name: survey_dt, dtype: int64

# %%
print(df['survey_dt'].min())
print(df['survey_dt'].max())
# Out:
# 2016-01-20 00:00:00
# 2020-08-18 00:00:00

# %% [markdown]
# ## Adding WAC official definitions

# %%
# Import the official WAC definitions
df_wac = pd.read_csv('../C_output_data/wac_codes_df_t338c97.csv')

# Join
df = df.join(df_wac.set_index('ttl_chp_sec'), on='wac_clean_short', how='left')

# Reorganize columns and eliminate obsolete ones
df = df[['pdf_name', 'page', 'image_based', 
         'letter_dt', 'survey_dt', 'survey_type', 'vendor_num', 'fed_num', 'aem_num', 'action',
         'fed_enforcement', 'nc_hist','epoc', 'state_rem', 'appeal_rights',
         'find_code', 'find_desc', 
         'wac_clean_long', 'wac_clean_short', 'sub_chp_num', 'sub_chp_name', 'section', 'ttl_chp_sec_desc',
         'cmp_item_num', 'cmp_total_num']]

# Renaming columns
df.columns = ['pdf_name', 'page', 'image_based', 
              'letter_dt', 'survey_dt', 'survey_type', 'vendor_num', 'fed_num', 'aem_num', 'action',
              'fed_enforcement', 'nc_hist','epoc', 'state_rem', 'appeal_rights',
              'finding_code', 'finding_desc', 
              'wac_long', 'wac_short', 'subchp_num', 'subchp_name', 'section', 'section_desc',
              'cmp_item', 'cmp_agg']

# %%
df.head()
# Out:
#                                      pdf_name page image_based  letter_dt  \
# 0  Advance Post Acute (G, CMP, CF) 4 6 18.pdf    1       False 2018-04-12
# 1  Advance Post Acute (G, CMP, CF) 4 6 18.pdf    2       False 2018-04-12
# 2  Advance Post Acute (G, CMP, CF) 4 6 18.pdf    3       False 2018-04-12
# 3  Advance Post Acute (G, CMP, CF) 4 6 18.pdf    4       False 2018-04-12
# 4  Advance Post Acute (G, CMP, CF) 4 6 18.pdf    5       False 2018-04-12
#
#    survey_dt                           survey_type vendor_num fed_num aem_num  \
# 0 2018-04-06  unannounced complaint investigation     4115441  505355  WADC9Q
# 1 2018-04-06  unannounced complaint investigation     4115441  505355  WADC9Q
# 2 2018-04-06  unannounced complaint investigation     4115441  505355  WADC9Q
# 3 2018-04-06  unannounced complaint investigation     4115441  505355  WADC9Q
# 4 2018-04-06  unannounced complaint investigation     4115441  505355  WADC9Q
#
#                       action fed_enforcement nc_hist   epoc state_rem  \
# 0  IMPOSITION OF CIVIL FINES           False   False   True     False
# 1  IMPOSITION OF CIVIL FINES           False   False  False      True
# 2  IMPOSITION OF CIVIL FINES           False   False  False     False
# 3  IMPOSITION OF CIVIL FINES           False   False  False     False
# 4  IMPOSITION OF CIVIL FINES           False   False  False     False
#
#   appeal_rights finding_code  \
# 0         False            G
# 1         False          NaN
# 2          True          NaN
# 3         False          NaN
# 4         False          NaN
#
#                                         finding_desc           wac_long  \
# 0  isolated deficiencies that constitute actual h...                NaN
# 1                                                NaN  388-97-1060(3)(g)
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
#      wac_short    subchp_num                                 subchp_name  \
# 0          NaN           NaN                                         NaN
# 1  388-97-1060  SUBCHAPTER I  RESIDENT RIGHTS, CARE AND RELATED SERVICES
# 2          NaN           NaN                                         NaN
# 3          NaN           NaN                                         NaN
# 4          NaN           NaN                                         NaN
#
#            section      section_desc  cmp_item  cmp_agg
# 0              NaN               NaN       NaN      NaN
# 1  Quality of Care  Quality of care.    1000.0      NaN
# 2              NaN               NaN       NaN      NaN
# 3              NaN               NaN       NaN   1000.0
# 4              NaN               NaN       NaN      NaN

# %%
df.tail()
# Out:
#                                                pdf_name page image_based  \
# 4953  Willapa_Harbor_Health_and_Rehab_February_3_201...    4       False
# 4954  Willapa_Harbor_Health_and_Rehab_February_3_201...    4       False
# 4955  Willapa_Harbor_Health_and_Rehab_February_3_201...    4       False
# 4956  Willapa_Harbor_Health_and_Rehab_February_3_201...    5       False
# 4957  Willapa_Harbor_Health_and_Rehab_February_3_201...    6       False
#
#       letter_dt  survey_dt                                        survey_type  \
# 4953 2017-02-03 2017-01-31  complaint investigation and partial extended s...
# 4954 2017-02-03 2017-01-31  complaint investigation and partial extended s...
# 4955 2017-02-03 2017-01-31  complaint investigation and partial extended s...
# 4956 2017-02-03 2017-01-31  complaint investigation and partial extended s...
# 4957 2017-02-03 2017-01-31  complaint investigation and partial extended s...
#
#      vendor_num fed_num aem_num action fed_enforcement nc_hist   epoc  \
# 4953    4113577  505349  WA6PHJ    NaN           False   False  False
# 4954    4113577  505349  WA6PHJ    NaN           False   False  False
# 4955    4113577  505349  WA6PHJ    NaN           False   False  False
# 4956    4113577  505349  WA6PHJ    NaN           False   False  False
# 4957    4113577  505349  WA6PHJ    NaN           False   False  False
#
#      state_rem appeal_rights finding_code finding_desc              wac_long  \
# 4953     False          True          NaN          NaN  388-97-0640(2)(a)(b)
# 4954     False          True          NaN          NaN     388-97-1060(3)(b)
# 4955     False          True          NaN          NaN        388-97-1620(1)
# 4956     False         False          NaN          NaN                   NaN
# 4957     False         False          NaN          NaN                   NaN
#
#         wac_short    subchp_num                                 subchp_name  \
# 4953  388-97-0640  SUBCHAPTER I  RESIDENT RIGHTS, CARE AND RELATED SERVICES
# 4954  388-97-1060  SUBCHAPTER I  RESIDENT RIGHTS, CARE AND RELATED SERVICES
# 4955  388-97-1620  SUBCHAPTER I  RESIDENT RIGHTS, CARE AND RELATED SERVICES
# 4956          NaN           NaN                                         NaN
# 4957          NaN           NaN                                         NaN
#
#               section             section_desc  cmp_item  cmp_agg
# 4953  Resident Rights     Prevention of abuse.    3000.0      NaN
# 4954  Quality of Care         Quality of care.    1000.0      NaN
# 4955   Administration  General administration.    3000.0      NaN
# 4956              NaN                      NaN       NaN  13000.0
# 4957              NaN                      NaN       NaN      NaN

# %% [markdown]
# # EXPORT RESULTS

# %%
df.to_csv('../C_output_data/scraped_data.csv', index=False)

# %% [markdown]
# # DATA INTEGRITY REVIEW

# %% [markdown]
# ### Did all the reports make it through?

# %%
assert df['pdf_name'].nunique() == len(df_letters)
print('The consistency test above confirms that all the', len(df_letters), 'enforcement letters made it through.')
# Out:
# The consistency test above confirms that all the 1035 enforcement letters made it through.

# %% [markdown]
# ### How many PDFs were image-based?

# %%
df_image = df[df['image_based']]

print('Out of the', len(df_letters), 'enforcement letter PDFs, apparently only', 
      df_image['pdf_name'].nunique(), 'of them contained image-based pages.',
      ' This does not necessarily mean that all pages in those PDFs are image-based, however. Let us confirm that:')
# Out:
# Out of the 1035 enforcement letter PDFs, apparently only 7 of them contained image-based pages.  This does not necessarily mean that all pages in those PDFs are image-based, however. Let us confirm that:

# %%
# List of all the pdf_names that have at least one image-based page
image_pdfs = df_image['pdf_name'].unique()
len(image_pdfs)

# Create a subset of df_all_reports that contains only the pdf_names that have at least one image-based page
df_one_report = df[df['pdf_name'].isin(image_pdfs)]

# Confirm all the pages in those PDFs are image-based
assert df_one_report['image_based'].all()
del(image_pdfs, df_one_report)

print('Indeed, if a report is identified as image-based, then all of its pages are image-based.')
# Out:
# Indeed, if a report is identified as image-based, then all of its pages are image-based.

# %%
df_image
# Out:
#                                                pdf_name page image_based  \
# 927   Cristwood Nursing and Rehab (GG, CMP, CF) 6 21...    1        True
# 928   Cristwood Nursing and Rehab (GG, CMP, CF) 6 21...    2        True
# 929   Cristwood Nursing and Rehab (GG, CMP, CF) 6 21...    3        True
# 930   Cristwood Nursing and Rehab (GG, CMP, CF) 6 21...    4        True
# 931   Cristwood Nursing and Rehab (GG, CMP, CF) 6 21...    5        True
# 962       Delta Rehab (IJ, R, SUB, CMP, CF) 6 14 18.pdf    1        True
# 963       Delta Rehab (IJ, R, SUB, CMP, CF) 6 14 18.pdf    2        True
# 964       Delta Rehab (IJ, R, SUB, CMP, CF) 6 14 18.pdf    3        True
# 965       Delta Rehab (IJ, R, SUB, CMP, CF) 6 14 18.pdf    4        True
# 966       Delta Rehab (IJ, R, SUB, CMP, CF) 6 14 18.pdf    5        True
# 1647  Heartwood Extended Health Care (amended-rescin...    1        True
# 1648  Heartwood Extended Health Care (amended-rescin...    2        True
# 1649    Heartwood Extended Health Care (rescind CF).pdf    1        True
# 1650    Heartwood Extended Health Care (rescind CF).pdf    2        True
# 3481    Tacoma Lutheran (Withdraw citation) 1 30 19.pdf    1        True
# 3558  The Gardens on Univeristy (Hx G, CMP, CF, prio...    1        True
# 3559  The Gardens on Univeristy (Hx G, CMP, CF, prio...    2        True
# 3560  The Gardens on Univeristy (Hx G, CMP, CF, prio...    3        True
# 3561  The Gardens on Univeristy (Hx G, CMP, CF, prio...    4        True
# 3562  The Gardens on Univeristy (Hx G, CMP, CF, prio...    5        True
# 4497  Lynnwood Post Acute (IJ, Pend, NR, SP, Cond) 7...    1        True
# 4498  Lynnwood Post Acute (IJ, Pend, NR, SP, Cond) 7...    2        True
# 4499  Lynnwood Post Acute (IJ, Pend, NR, SP, Cond) 7...    3        True
# 4500  Lynnwood Post Acute (IJ, Pend, NR, SP, Cond) 7...    4        True
#
#      letter_dt survey_dt survey_type vendor_num fed_num aem_num action  \
# 927        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 928        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 929        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 930        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 931        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 962        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 963        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 964        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 965        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 966        NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 1647       NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 1648       NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 1649       NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 1650       NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 3481       NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 3558       NaT       NaT         NaN        NaN     NaN     NaN    NaN
# 3562          NaN      NaN       NaN        NaN         NaN     NaN
# 4497          NaN      NaN       NaN        NaN         NaN     NaN
# 4498          NaN      NaN       NaN        NaN         NaN     NaN
# 4499          NaN      NaN       NaN        NaN         NaN     NaN
# 4500          NaN      NaN       NaN        NaN         NaN     NaN
#
#      section_desc  cmp_item  cmp_agg
# 927           NaN       NaN      NaN
# 928           NaN       NaN      NaN
# 929           NaN       NaN      NaN
# 930           NaN       NaN      NaN
# 931           NaN       NaN      NaN
# 962           NaN       NaN      NaN
# 963           NaN       NaN      NaN
# 964           NaN       NaN      NaN
# 965           NaN       NaN      NaN
# 966           NaN       NaN      NaN
# 1647          NaN       NaN      NaN
# 1648          NaN       NaN      NaN
# 1649          NaN       NaN      NaN
# 1650          NaN       NaN      NaN
# 3481          NaN       NaN      NaN
# 3558          NaN       NaN      NaN
# 3559          NaN       NaN      NaN
# 3560          NaN       NaN      NaN
# 3561          NaN       NaN      NaN
# 3562          NaN       NaN      NaN
# 4497          NaN       NaN      NaN
# 4498          NaN       NaN      NaN
# 4499          NaN       NaN      NaN
# 4500          NaN       NaN      NaN

# %% [markdown]
# Saved down copies of the image-based files to inspect visually.

# %% [markdown]
# ### Close look at those stratospheric fines

# %% [markdown]
# There are a few unusual fines. Although they are rare—each only shows up once—they are stratospheric.
#
# They are so big, it is worth to take a close look at them. One test that is worth doing is whether the sum of the individual WAC fines adds up to the sum of the total fines for this particular group.

# %%
df['cmp_item'].value_counts(dropna=False)
# Out:
# NaN          3897
# 1000.00       525
# 3000.00       191
# 500.00        119
# 2000.00       103
# 1500.00        86
# 2500.00         3
# 98778.43        1
# 536.40          1
# 11152.70        1
# 4046.56         1
# 3350.18         1
# 33412.96        1
# 96909.62        1
# 4415.58         1
# 8849.46         1
# 52720.56        1
# 250.00          1
# 8858.00         1
# 9094.35         1
# 15800.40        1
# 8872.63         1
# 29830.14        1
# 190835.73       1
# 2173.25         1
# 35904.06        1
# 5591.52         1
# 7662.23         1
# 44745.68        1
# 37371.36        1
# 14080.91        1
# 17990.78        1
# 52163.05        1
# 69282.25        1
# 13823.65        1
# 2544.65         1
# 37851.09        1
# 115519.72       1
# 9166.88         1
# 8124.16         1
# 9259.58         1
# Name: cmp_item, dtype: int64

# %%
# List all the cmp_item values and the number of times they appear through the reports
mega_cmp_list = df['cmp_item'].value_counts(dropna=False).reset_index()
mega_cmp_list.columns = ['cmp_item', 'freq']
# Filter for only the unusual cmp_item amounts
mega_cmp_list = mega_cmp_list[mega_cmp_list['freq'] == 1].reset_index(drop=True)
# Reduce it to a series that contains those mega cmp
mega_cmp_list = mega_cmp_list['cmp_item']
mega_cmp_list
# Out:
# 0      98778.43
# 1        536.40
# 2      11152.70
# 3       4046.56
# 4       3350.18
# 5      33412.96
# 6      96909.62
# 7       4415.58
# 8       8849.46
# 9      52720.56
# 10       250.00
# 11      8858.00
# 12      9094.35
# 13     15800.40
# 14      8872.63
# 15     29830.14
# 16    190835.73
# 17      2173.25
# 18     35904.06
# 19      5591.52
# 20      7662.23
# 21     44745.68
# 22     37371.36
# 23     14080.91
# 24     17990.78
# 25     52163.05
# 26     69282.25
# 27     13823.65
# 28      2544.65
# 29     37851.09
# 30    115519.72
# 31      9166.88
# 32      8124.16
# 33      9259.58
# Name: cmp_item, dtype: float64

# %%
# Create a subset of df with only the pdf_names that contain those unusual cmp
df_mega_cmp = df[df['cmp_item'].isin(mega_cmp_list)]
df_mega_cmp = df[df['pdf_name'].isin(df_mega_cmp['pdf_name'].unique())]
df_mega_cmp
# Out:
#                                                pdf_name page image_based  \
# 571   Brookfield Cascadia (Hx, GG, Amend DCH, Prior ...    1       False
# 572   Brookfield Cascadia (Hx, GG, Amend DCH, Prior ...    2       False
# 573   Brookfield Cascadia (Hx, GG, Amend DCH, Prior ...    3       False
# 574   Brookfield Cascadia (Hx, GG, Amend DCH, Prior ...    4       False
# 575   Brookfield Cascadia (Hx, GG, Amend DCH, Prior ...    5       False
# ...                                                 ...  ...         ...
# 4487       Crestwood Health and Rehab (DCH) 7 10 20.pdf    4       False
# 4507        Montesano Health and Rehab (DCH) 7 8 20.pdf    1       False
# 4508        Montesano Health and Rehab (DCH) 7 8 20.pdf    2       False
# 4509        Montesano Health and Rehab (DCH) 7 8 20.pdf    3       False
# 4510        Montesano Health and Rehab (DCH) 7 8 20.pdf    4       False
#
#       letter_dt  survey_dt                           survey_type vendor_num  \
# 571  2018-04-23 2018-04-12              complaint investigation     4115521
# 572  2018-04-23 2018-04-12              complaint investigation     4115521
# 573  2018-04-23 2018-04-12              complaint investigation     4115521
# 574  2018-04-23 2018-04-12              complaint investigation     4115521
# 575  2018-04-23 2018-04-12              complaint investigation     4115521
# ...         ...        ...                                   ...        ...
# 4487 2020-07-16 2020-07-10  unannounced complaint investigation     4115621
# 4507 2020-07-16 2020-07-08  unannounced complaint investigation     4115301
# 4508 2020-07-16 2020-07-08  unannounced complaint investigation     4115301
# 4509 2020-07-16 2020-07-08  unannounced complaint investigation     4115301
# 4510 2020-07-16 2020-07-08  unannounced complaint investigation     4115301
#
#      fed_num aem_num                     action fed_enforcement nc_hist  \
# 571   505331  WAS3K4  IMPOSITION OF CIVIL FINES           False    True
# 572   505331  WAS3K4  IMPOSITION OF CIVIL FINES           False   False
# 573   505331  WAS3K4  IMPOSITION OF CIVIL FINES           False   False
# 574   505331  WAS3K4  IMPOSITION OF CIVIL FINES           False   False
# 575   505331  WAS3K4  IMPOSITION OF CIVIL FINES           False   False
# ...      ...     ...                        ...             ...     ...
# 4487  505185     NaN                        NaN           False   False
# 4507  505503     NaN                        NaN           False   False
# 4508  505503     NaN                        NaN           False   False
# 4509  505503     NaN                        NaN           False   False
# 4510  505503     NaN                        NaN           False   False
#
#        epoc state_rem appeal_rights finding_code  \
# 571   False     False         False            G
# 572   False     False         False            G
# 573    True      True          True          NaN
# 574   False     False         False          NaN
# 575   False     False         False          NaN
# ...     ...       ...           ...          ...
# 4487  False     False         False          NaN
# 4507  False     False         False          NaN
# 4508  False      True          True          NaN
# 4509  False     False         False          NaN
# 4510  False     False         False          NaN
#
#                                            finding_desc  \
# 571   isolated deficiencies that constitute actual h...
# 572   isolated deficiencies that constitute actual h...
# 573                                                 NaN
# 574                                                 NaN
# 575                                                 NaN
# ...                                                 ...
# 4487                                                NaN
# 4507                                                NaN
# 4508                                                NaN
# 4509                                                NaN
# 4510                                                NaN
#
#                         wac_long    wac_short    subchp_num  \
# 571                          NaN          NaN           NaN
# 572               388-97-1090(1)  388-97-1090  SUBCHAPTER I
# 573            388-97-1060(3)(g)  388-97-1060  SUBCHAPTER I
# 574                          NaN          NaN           NaN
# 575                          NaN          NaN           NaN
# ...                          ...          ...           ...
# 4487                         NaN          NaN           NaN
# 4507                         NaN          NaN           NaN
# 4508  388-97-1090(1)(8)(a)(b)(d)  388-97-1090  SUBCHAPTER I
# 4509                         NaN          NaN           NaN
# 4510                         NaN          NaN           NaN
#
#                                      subchp_name           section  \
# 571                                          NaN               NaN
# 572   RESIDENT RIGHTS, CARE AND RELATED SERVICES  Nursing Services
# 573   RESIDENT RIGHTS, CARE AND RELATED SERVICES   Quality of Care
# 574                                          NaN               NaN
# 575                                          NaN               NaN
# ...                                          ...               ...
# 4487                                         NaN               NaN
# 4507                                         NaN               NaN
# 4508  RESIDENT RIGHTS, CARE AND RELATED SERVICES  Nursing Services
# 4509                                         NaN               NaN
# 4510                                         NaN               NaN
#
#             section_desc  cmp_item  cmp_agg
# 571                  NaN       NaN      NaN
# 572   Direct care hours.   8872.63      NaN
# 573     Quality of care.   1000.00      NaN
# 574                  NaN       NaN      NaN
# 575                  NaN       NaN  9872.63
# ...                  ...       ...      ...
# 4487                 NaN       NaN      NaN
# 4507                 NaN       NaN      NaN
# 4508  Direct care hours.   9259.58      NaN
# 4509                 NaN       NaN  9259.58
# 4510                 NaN       NaN      NaN
#
# [148 rows x 25 columns]

# %%
# Consistency test: are all the unsual cmp_item values in this new data frame?
assert mega_cmp_list.isin(df_mega_cmp['cmp_item']).all()

# Are the sums of individual fines and total fines consistent for this group of mega fines?
print('There is a slight difference of', df_mega_cmp['cmp_item'].sum() - df_mega_cmp['cmp_agg'].sum(),
      'out of a total', df_mega_cmp['cmp_agg'].sum(), 'or', 
     round((df_mega_cmp['cmp_item'].sum() - df_mega_cmp['cmp_agg'].sum()) / df_mega_cmp['cmp_agg'].sum()*100,1),
     '%')
# Out:
# There is a slight difference of 5500.0 out of a total 1064968.52 or 0.5 %

# %% [markdown]
# Note: A separate visual analysis these mega fines show that mostly correspond to a particular code violation: [WAC 388-97-1090(1)](https://apps.leg.wa.gov/wac/default.aspx?cite=388-97-1090), a Quality of Care related code that regulates the minimum hours of direct care per resident day (HDR) that a nursing home must provide.

# %% [markdown]
# ### From how many reports were we able to extract a total mulct amount?

# %%
temp = df[~df['cmp_agg'].isna()]

print(len(temp))
print(temp['pdf_name'].nunique())
# Out:
# 635
# 634

# %% [markdown]
# There seems to be one report that has 2 total amounts. Let's check.

# %%
temp = temp['pdf_name'].value_counts().reset_index()
x = temp[temp['pdf_name'] > 1].loc[0, 'index']
x
# Out:
# 'Cheney Care Center Amended by hearing 2 (G, CMP, CF) 9 8 17.pdf'

# %%
df[df['pdf_name'] == x]
# Out:
#                                               pdf_name page image_based  \
# 699  Cheney Care Center Amended by hearing 2 (G, CM...    1       False
# 700  Cheney Care Center Amended by hearing 2 (G, CM...    2       False
# 701  Cheney Care Center Amended by hearing 2 (G, CM...    2       False
# 702  Cheney Care Center Amended by hearing 2 (G, CM...    3       False
#
#      letter_dt  survey_dt               survey_type vendor_num fed_num  \
# 699 2018-08-22 2017-09-08  complaint investigation     4173209  505346
# 700 2018-08-22 2017-09-08  complaint investigation     4173209  505346
# 701 2018-08-22 2017-09-08  complaint investigation     4173209  505346
# 702 2018-08-22 2017-09-08  complaint investigation     4173209  505346
#
#     aem_num                     action fed_enforcement nc_hist   epoc  \
# 699  WANOSW  IMPOSITION OF CIVIL FINES           False   False   True
# 700  WANOSW  IMPOSITION OF CIVIL FINES           False   False  False
# 701  WANOSW  IMPOSITION OF CIVIL FINES           False   False  False
# 702  WANOSW  IMPOSITION OF CIVIL FINES           False   False  False
#
#     state_rem appeal_rights finding_code finding_desc           wac_long  \
# 699     False         False          NaN          NaN                NaN
# 700      True         False          NaN          NaN  388-97-1620(2)(b)
# 701      True         False          NaN          NaN     388-97-1060(1)
# 702     False         False          NaN          NaN                NaN
#
#        wac_short    subchp_num                                 subchp_name  \
# 699          NaN           NaN                                         NaN
# 700  388-97-1620  SUBCHAPTER I  RESIDENT RIGHTS, CARE AND RELATED SERVICES
# 701  388-97-1060  SUBCHAPTER I  RESIDENT RIGHTS, CARE AND RELATED SERVICES
# 702          NaN           NaN                                         NaN
#
#              section             section_desc  cmp_item  cmp_agg
# 699              NaN                      NaN       NaN      NaN
# 700   Administration  General administration.    1000.0   2500.0
# 701  Quality of Care         Quality of care.    1500.0   2500.0
# 702              NaN                      NaN       NaN      NaN

# %% [markdown]
# ### Findings

# %%
print(df['finding_code'].nunique())
df['finding_code'].value_counts(dropna=False)
# Out:
# 9
# NaN    3903
# G       513
# D       241
# E        90
# J        69
# F        53
# K        47
# L        23
# H        17
# I         2
# Name: finding_code, dtype: int64

# %%
print(df['finding_desc'].nunique())
df['finding_desc'].value_counts(dropna=False)
# Out:
# 50
# NaN                                                                                                                                                                                                                                                                                                                                                                                     3903
# isolated deficiencies that constitute actual harm that is not immediate jeopardy                                                                                                                                                                                                                                                                                                         477
# isolated deficiencies that constitute no actual harm with potential for more than minimal harm that is not immediate jeopardy                                                                                                                                                                                                                                                            210
# isolated deficiencies constituting immediate jeopardy to resident health and safety                                                                                                                                                                                                                                                                                                       57
# widespread deficiencies that constitute no actual harm with potential for more than minimal harm that is not immediate jeopardy                                                                                                                                                                                                                                                           47
# a pattern of deficiencies that constitute no actual harm that is not immediate jeopardy                                                                                                                                                                                                                                                                                                   40
# a pattern of deficiencies that constitute immediate jeopardy to resident health and safety                                                                                                                                                                                                                                                                                                37
# isolated deficiencies that constitute no actual harm with potential for more than minimal harm that is not immediate jeopardy, as evidenced by the CMS Form 2567L                                                                                                                                                                                                                         28
# isolated deficiencies that constitute no actual harm with potential for more than minimal harm that is not immediate jeopardy   History of Non-Compliance    On September 11, 2018, DSHS and the Office of the State Fire Marshal                                                                                                                                                         1
# a pattern of deficiencies that constitute immediate jeopardy to resident health and safety   You were informed of the immediate jeopardy deficiencies on July 10, 2020                                                                                                                                                                                                                     1
# widespread deficiencies that constitute no actual harm with potential for more     than minimal harm that is not immediate jeopardy, as evidenced by the   attached CMS Form 2567L                                                                                                                                                                                                         1
# widespread deficiencies that constitute immediate jeopardy to resident health and safety                                                                                                                                                                                                                                                                                                   1
# a pattern of deficiencies that constitute immediate jeopardy to resident health and safety, in 42 CFR 483                                                                                                                                                                                                                                                                                  1
# Widespread deficiencies constituting immediate jeopardy to resident health and safety, in 42 CFR 483                                                                                                                                                                                                                                                                                       1
# a pattern of deficiencies constituting immediate jeopardy to resident health and safety                                                                                                                                                                                                                                                                                                    1
# Widespread deficiencies constituting immediate jeopardy to resident health and safety in K712                                                                                                                                                                                                                                                                                              1
# isolated and constituting immediate jeopardy to resident health and safety, that occurred on January 18, 2018                                                                                                                                                                                                                                                                              1
# isolated deficiencies constituting immediate jeopardy to resident health and safety 42 CFR 483                                                                                                                                                                                                                                                                                             1
# widespread deficiencies that constitute no actual harm with potential for more than minimal harm that is not immediate jeopardy  History of Non-Compliance    On May 10, 2019, DSHS and the Office of the State Fire Marshal                                                                                                                                                              1
# a pattern of deficiencies that constitute no actual harm with a potential for more than minimal harm that is not immediate jeopardy                                                                                                                                                                                                                                                        1
# widespread deficiencies that constitute no actual harm with potential for more than minimal harm that is not immediate jeopardy, as evidenced by the attached CMS Form 2567L                                                                                                                                                                                                               1
# Widespread deficiencies that constitute no actual harm with a potential for more than minimal harm that is not an immediate jeopardy                                                                                                                                                                                                                                                       1
# isolated deficiencies that constitute no actual harm with potential for more than minimal harm that is not immediate jeopardy   History of Non-Compliance    On April 3, 2019, DSHS conducted an unannounced complaint investigation at your facility                                                                                                                                     1
# A pattern of deficiencies that constitute no actual harm with a potential for more than minimal harm that is not an immediate jeopardy                                                                                                                                                                                                                                                     1
# isolated deficiencies that constitute no actual harm with potential for more than minimal harm that is not immediate jeopardy,     In a letter dated January 28, 2019 you were notified about the January 18, 2019 survey findings and informed that if your facility fails to achieve substantial compliance by correcting the deficiencies on the Health survey by March 18, 2019       1
# isolated deficiencies that constitute actual harm that is not   immediate jeopardy, as evidenced by the attached CMS Form 2567L                                                                                                                                                                                                                                                            1
# pattern of deficiencies constituting immediate jeopardy to resident health and safety                                                                                                                                                                                                                                                                                                      1
# Name: finding_desc, dtype: int64

# %% [markdown]
# Ther are far more descriptions for a finding than codes. That is, a single finding code has typically multiple descriptions.
#
# Unless the official finding descriptions have changed over time, each code should only have one description. It seems that the problem here might arise from typos or because the algorithm picked up noise text when scraping for the descriptions. We should base our analysis in the finding codes instead of the descriptions and confirm that their definitions have not changed over time.

# %% [markdown]
# ### Date consistency

# %% [markdown]
# Logically, all survey dates should precede their corresponding enforcement letter dates. Let's see if we can find instances where that is not the case.

# %%
print(df[(df['letter_dt'] <= df['survey_dt'])]['pdf_name'].unique())
df[(df['letter_dt'] <= df['survey_dt'])]#[['pdf_name', 'letter_dt','survey_dt']].drop_duplicates()
# Out:
# ['Alderwood Park (G, CMP, CF) 1 3 20.pdf'
#  'Talbot Center (Hx, D prior IJ, R, SUB, CMP, CF) 9 17.pdf'
#  'University Place Care Center (Hx G prior K, Cond) 10 21 19.pdf']
#                                                pdf_name page image_based  \
# 126              Alderwood Park (G, CMP, CF) 1 3 20.pdf    1       False
# 127              Alderwood Park (G, CMP, CF) 1 3 20.pdf    2       False
# 128              Alderwood Park (G, CMP, CF) 1 3 20.pdf    3       False
# 129              Alderwood Park (G, CMP, CF) 1 3 20.pdf    4       False
# 130              Alderwood Park (G, CMP, CF) 1 3 20.pdf    5       False
# 3520  Talbot Center (Hx, D prior IJ, R, SUB, CMP, CF...    1       False
# 3521  Talbot Center (Hx, D prior IJ, R, SUB, CMP, CF...    2       False
# 3522  Talbot Center (Hx, D prior IJ, R, SUB, CMP, CF...    3       False
# 3523  Talbot Center (Hx, D prior IJ, R, SUB, CMP, CF...    4       False
# 3524  Talbot Center (Hx, D prior IJ, R, SUB, CMP, CF...    5       False
# 3732  University Place Care Center (Hx G prior K, Co...    1       False
# 3733  University Place Care Center (Hx G prior K, Co...    2       False
# 3734  University Place Care Center (Hx G prior K, Co...    3       False
# 3735  University Place Care Center (Hx G prior K, Co...    4       False
# 3736  University Place Care Center (Hx G prior K, Co...    5       False
#
#       letter_dt  survey_dt                                        survey_type  \
# 126  2020-01-14 2020-01-20               unannounced complaint investigation
# 127  2020-01-14 2020-01-20               unannounced complaint investigation
# 128  2020-01-14 2020-01-20               unannounced complaint investigation
# 129  2020-01-14 2020-01-20               unannounced complaint investigation
# 130  2020-01-14 2020-01-20               unannounced complaint investigation
# 3520 2017-08-29 2017-08-30  unannounced abbreviated survey and partial ext...
# 3521 2017-08-29 2017-08-30  unannounced abbreviated survey and partial ext...
# 3522 2017-08-29 2017-08-30  unannounced abbreviated survey and partial ext...
# 3523 2017-08-29 2017-08-30  unannounced abbreviated survey and partial ext...
# 3524 2017-08-29 2017-08-30  unannounced abbreviated survey and partial ext...
# 3732 2019-10-18 2019-10-21               unannounced complaint investigation
# 3733 2019-10-18 2019-10-21               unannounced complaint investigation
# 3734 2019-10-18 2019-10-21               unannounced complaint investigation
# 3735 2019-10-18 2019-10-21               unannounced complaint investigation
# 3736 2019-10-18 2019-10-21               unannounced complaint investigation
#
#      vendor_num fed_num aem_num                                     action  \
# 126     4114602  505092  WAOYRU                 IMPOSITION OF A CIVIL FINE
# 127     4114602  505092  WAOYRU                 IMPOSITION OF A CIVIL FINE
# 128     4114602  505092  WAOYRU                 IMPOSITION OF A CIVIL FINE
# 129     4114602  505092  WAOYRU                 IMPOSITION OF A CIVIL FINE
# 130     4114602  505092  WAOYRU                 IMPOSITION OF A CIVIL FINE
# 3520    4113114  505202  WAVEO1                                        NaN
# 3521    4113114  505202  WAVEO1                                        NaN
# 3522    4113114  505202  WAVEO1                                        NaN
# 3523    4113114  505202  WAVEO1                                        NaN
# 3524    4113114  505202  WAVEO1                                        NaN
# 3732    4115531  505473  WAJWLE  IMPOSITION OF NEW CONDITIONS ON A LICENSE
# 3733    4115531  505473  WAJWLE  IMPOSITION OF NEW CONDITIONS ON A LICENSE
# 3734    4115531  505473  WAJWLE  IMPOSITION OF NEW CONDITIONS ON A LICENSE
# 3735    4115531  505473  WAJWLE  IMPOSITION OF NEW CONDITIONS ON A LICENSE
# 3736    4115531  505473  WAJWLE  IMPOSITION OF NEW CONDITIONS ON A LICENSE
#
#      fed_enforcement nc_hist   epoc state_rem appeal_rights finding_code  \
# 126            False   False   True     False         False            G
# 127            False   False  False      True         False          NaN
# 128            False   False  False     False          True          NaN
# 129            False   False  False     False         False          NaN
# 130            False   False  False     False         False          NaN
# 3520           False    True  False     False         False            D
# 3521           False   False   True     False         False          NaN
# 3522           False   False  False      True          True          NaN
# 3523           False   False  False     False         False          NaN
# 3524           False   False  False     False         False          NaN
# 3732           False    True  False     False         False            G
# 3733           False   False   True      True         False          NaN
# 3734           False   False  False     False          True          NaN
# 3735           False   False  False     False         False          NaN
# 3736           False   False  False     False         False          NaN
#
#                                            finding_desc           wac_long  \
# 126   isolated deficiencies that constitute actual h...                NaN
# 127                                                 NaN  388-97-1060(3)(b)
# 128                                                 NaN                NaN
# 129                                                 NaN                NaN
# 130                                                 NaN                NaN
# 3520  isolated deficiencies that constitute no actua...                NaN
# 3521                                                NaN                NaN
# 3522                                                NaN                NaN
# 3523                                                NaN                NaN
# 3524                                                NaN                NaN
# 3732  isolated deficiencies that constitute actual h...                NaN
# 3733                                                NaN                NaN
# 3734                                                NaN                NaN
# 3735                                                NaN                NaN
# 3736                                                NaN                NaN
#
#         wac_short    subchp_num                                 subchp_name  \
# 126           NaN           NaN                                         NaN
# 127   388-97-1060  SUBCHAPTER I  RESIDENT RIGHTS, CARE AND RELATED SERVICES
# 128           NaN           NaN                                         NaN
# 129           NaN           NaN                                         NaN
# 130           NaN           NaN                                         NaN
# 3520          NaN           NaN                                         NaN
# 3521          NaN           NaN                                         NaN
# 3522          NaN           NaN                                         NaN
# 3523          NaN           NaN                                         NaN
# 3524          NaN           NaN                                         NaN
# 3732          NaN           NaN                                         NaN
# 3733          NaN           NaN                                         NaN
# 3734          NaN           NaN                                         NaN
# 3735          NaN           NaN                                         NaN
# 3736          NaN           NaN                                         NaN
#
#               section      section_desc  cmp_item  cmp_agg
# 126               NaN               NaN       NaN      NaN
# 127   Quality of Care  Quality of care.    1000.0      NaN
# 128               NaN               NaN       NaN      NaN
# 129               NaN               NaN       NaN   1000.0
# 130               NaN               NaN       NaN      NaN
# 3520              NaN               NaN       NaN      NaN
# 3521              NaN               NaN       NaN      NaN
# 3522              NaN               NaN       NaN      NaN
# 3523              NaN               NaN       NaN      NaN
# 3524              NaN               NaN       NaN      NaN
# 3732              NaN               NaN       NaN      NaN
# 3733              NaN               NaN       NaN      NaN
# 3734              NaN               NaN       NaN      NaN
# 3735              NaN               NaN       NaN      NaN
# 3736              NaN               NaN       NaN      NaN
